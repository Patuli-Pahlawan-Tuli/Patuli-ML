# %% [markdown]
# ---
#
# # Patuli (C23-PS037) - Bangkit 2023 Capstone Project
#
# ---
#
# ## [**Numbers**] Model Training
#
# ---
#
# **Author:** Ammar Sufyan, Fauzan Farhan Antoro, Belvin Shandy Aurora
#
# **Github:** https://github.com/Patuli-Pahlawan-Tuli/Patuli-ML

# %% [markdown]
# # 1.&nbsp;Gather and Label Training Images

# %% [markdown]
# We first collected the Bisindo sign language dataset.
# *   For the alphabetical (A-Z) dataset we took from [here](https://www.kaggle.com/datasets/nando645/bisindo2).
# *   For the number and word datasets, we created our own by taking a photo of ourselves.

# %% [markdown]
# Next, after we finished collecting the dataset, we performed labeling using [label-studio](https://github.com/heartexlabs/label-studio).
#
# ![Screenshot 2023-06-03 105414.png](data:image/png;base64,...)

# %% [markdown]
# # 2.&nbsp;Install TensorFlow Object Detection Dependencies

# %%
# !pip install tensorflow==2.8.0
# !pip install protobuf==3.20.*
# Out:
# Collecting tensorflow==2.8.0
#   Using cached tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497.6 MB)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (44.0.0)
# Collecting keras<2.9,>=2.8.0rc0
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Collecting numpy>=1.20
#   Using cached numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting gast>=0.2.1
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting libclang>=9.0.1
#   Using cached libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (4.6.3)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Collecting absl-py>=0.4.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-4.23.2-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
# Collecting tensorboard<2.9,>=2.8
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.54.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers>=1.12
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.15.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.16.0)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.19.1-py2.py3-none-any.whl (181 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting werkzeug>=0.11.15
#   Using cached Werkzeug-2.3.4-py3-none-any.whl (242 kB)
# Collecting wheel>=0.26
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<2.0
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (6.6.0)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.15.0)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: keras, numpy, gast, tf-estimator-nightly, libclang, tensorflow-io-gcs-filesystem, absl-py, protobuf, tensorboard-data-server, grpcio, cachetools, pyasn1, rsa, urllib3, pyasn1-modules, google-auth, idna, charset-normalizer, certifi, requests, tensorboard-plugin-wit, markdown, MarkupSafe, werkzeug, wheel, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, google-pasta, flatbuffers, wrapt, astunparse, keras-preprocessing, h5py, opt-einsum, termcolor, tensorflow
# Successfully installed MarkupSafe-2.1.3 absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 certifi-2023.5.7 charset-normalizer-3.1.0 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.19.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.54.2 h5py-3.8.0 idna-3.4 keras-2.8.0 keras-preprocessing-1.1.2 libclang-16.0.0 markdown-3.4.3 numpy-1.24.3 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.2 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.3.0 tf-estimator-nightly-2.8.0.dev2021122109 urllib3-1.26.16 werkzeug-2.3.4 wheel-0.40.0 wrapt-1.15.0
# Collecting protobuf==3.20.*
#   Using cached protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.2
#     Uninstalling protobuf-4.23.2:
#       Successfully uninstalled protobuf-4.23.2
# Successfully installed protobuf-3.20.3
# [sudo] password for dadang:

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0
# 2023-06-03 19:23:11.069709: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 19:23:11.215280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.221564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.221812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.867784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.868279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.868299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 19:23:11.868581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.868638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-06-03 19:23:11.869888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.870161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.870416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.870789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.870802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 19:23:11.871062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:23:11.871095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Clone the tensorflow models repository from GitHub
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3843, done.
# remote: Counting objects: 100% (3843/3843), done.
# remote: Compressing objects: 100% (2955/2955), done.
# remote: Total 3843 (delta 1109), reused 1955 (delta 837), pack-reused 0
# Receiving objects: 100% (3843/3843), 49.59 MiB | 4.64 MiB/s, done.
# Resolving deltas: 100% (1109/1109), done.

# %%
# Copy setup files into models/research folder (Run in terminal)
# %bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# Modify setup.py file to install the tf-models-official repository targeted at TF v2.8.0
import re
with open('models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# Install the Object Detection API
# !pip install models/research/
# Out:
# Processing ./models/research
# Requirement already satisfied: Cython in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (0.29.35)
# Requirement already satisfied: apache-beam in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.48.0)
# Requirement already satisfied: avro-python3 in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: contextlib2 in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: keras in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: lvis in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: lxml in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.0.2)
# Requirement already satisfied: pillow in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (9.5.0)
# Requirement already satisfied: pycocotools in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: pyparsing==2.4.7 in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: tensorflow_io in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (0.32.0)
# Requirement already satisfied: tf-models-official==2.8.0 in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: tf-slim in ./venv/lib/python3.8/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: numpy<1.25.0,>=1.14.3 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.24.3)
# Requirement already satisfied: pytz>=2018.3 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2023.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (4.6.3)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.54.2)
# Requirement already satisfied: fasteners<1.0,>=0.3 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: crcmod<2.0,>=1.7 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: regex>=2020.6.8 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2023.5.5)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: orjson<4.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.9.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.8.2)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: cloudpickle~=2.2.1 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: zstandard<1,>=0.18.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (4.3.3)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (11.0.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in ./venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.7.4)
# Requirement already satisfied: kiwisolver>=1.1.0 in ./venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in ./venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (0.10.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in ./venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (4.39.4)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: portalocker in ./venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: tabulate>=0.8.9 in ./venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: colorama in ./venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in ./venv/lib/python3.8/site-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: tensorflow-text~=2.8.0 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (9.0.0)
# Requirement already satisfied: tensorflow-addons in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.20.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.4.1)
# Requirement already satisfied: oauth2client in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.1.3)
# Requirement already satisfied: sentencepiece in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.1.99)
# Requirement already satisfied: kaggle>=1.3.9 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.5.13)
# Requirement already satisfied: google-api-python-client>=1.6.7 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.88.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.7.5)
# Requirement already satisfied: gin-config in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: psutil>=5.4.3 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.9.5)
# Requirement already satisfied: opencv-python-headless in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: seqeval in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow~=2.8.0 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.13.0)
# Requirement already satisfied: tensorflow-datasets in ./venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.9.2)
# Requirement already satisfied: absl-py>=0.2.2 in ./venv/lib/python3.8/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: docopt in ./venv/lib/python3.8/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./venv/lib/python3.8/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.3.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in ./venv/lib/python3.8/site-packages (from tensorflow-addons->tf-models-official==2.8.0->object-detection==0.1) (2.13.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in ./venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.3.0)
# Requirement already satisfied: pyasn1>=0.1.7 in ./venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: rsa>=3.1.4 in ./venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (4.9)
# Requirement already satisfied: tqdm in ./venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in ./venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (8.0.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in ./venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.19.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in ./venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in ./venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (4.1.1)
# Requirement already satisfied: dm-tree~=0.1.1 in ./venv/lib/python3.8/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0->object-detection==0.1) (0.1.8)
# Requirement already satisfied: scikit-learn>=0.21.3 in ./venv/lib/python3.8/site-packages (from seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: h5py>=2.9.0 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.8.0)
# Requirement already satisfied: gast>=0.2.1 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.5.4)
# Requirement already satisfied: libclang>=9.0.1 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (16.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (44.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0.dev2021122109)
# Requirement already satisfied: termcolor>=1.1.0 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.15.0)
# Requirement already satisfied: flatbuffers>=1.12 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (23.5.26)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.3.0)
# Requirement already satisfied: toml in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.10.2)
# Requirement already satisfied: click in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (8.1.3)
# Requirement already satisfied: array-record in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: promise in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.13.1)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in ./venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.3.0)
# Requirement already satisfied: text-unidecode>=1.3 in ./venv/lib/python3.8/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv/lib/python3.8/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (5.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in ./venv/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (1.59.0)
# Requirement already satisfied: joblib>=1.1.1 in ./venv/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.40.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.4.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (6.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697016 sha256=83e8ee95001ea13f7fd249cffae5c1d0d6d0f2e5c667e676d3b89553fbe29529
#   Stored in directory: /tmp/pip-ephem-wheel-cache-en00nbh2/wheels/87/09/b9/238821045dbe1e65485e5d94585ca1cbeef85e56808153d912
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1

# %%
# Run Model Builder Test file, just to verify everything's working properly
# !python3 models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-06-03 19:24:19.659684: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:19.665346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:19.665625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# Running tests under Python 3.8.10: /home/dadang/Documents/ML/Bangkit/train_huruf/venv/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-06-03 19:24:19.677690: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 19:24:19.678888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:19.679321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:19.679642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:20.137988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:20.138365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:20.138390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 19:24:20.138672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:24:20.138771: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/builders/model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0603 19:24:21.137058 140023962949440 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.63s
# I0603 19:24:21.300673 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.63s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.29s
# I0603 19:24:21.593684 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.29s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.14s
# I0603 19:24:21.732588 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.2s
# I0603 19:24:21.931065 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.2s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.13s
# I0603 19:24:23.063171 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.13s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0603 19:24:23.064148 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# I0603 19:24:23.078544 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0603 19:24:23.086919 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0603 19:24:23.095928 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# I0603 19:24:23.155186 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# I0603 19:24:23.207929 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# I0603 19:24:23.263520 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# I0603 19:24:23.319867 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# I0603 19:24:23.374216 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0603 19:24:23.390635 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0603 19:24:23.591296 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0603 19:24:23.591531 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0603 19:24:23.591593 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0603 19:24:23.593261 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:23.605857 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:23.605993 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:23.656405 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:23.656536 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:23.760135 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:23.760274 140023962949440 efficientnet_model.py:144] round_filter input=40 output=40
# I0603 19:24:23.868854 140023962949440 efficientnet_model.py:144] round_filter input=40 output=40
# I0603 19:24:23.869015 140023962949440 efficientnet_model.py:144] round_filter input=80 output=80
# I0603 19:24:24.029246 140023962949440 efficientnet_model.py:144] round_filter input=80 output=80
# I0603 19:24:24.029383 140023962949440 efficientnet_model.py:144] round_filter input=112 output=112
# I0603 19:24:24.197534 140023962949440 efficientnet_model.py:144] round_filter input=112 output=112
# I0603 19:24:24.197682 140023962949440 efficientnet_model.py:144] round_filter input=192 output=192
# I0603 19:24:24.407436 140023962949440 efficientnet_model.py:144] round_filter input=192 output=192
# I0603 19:24:24.407590 140023962949440 efficientnet_model.py:144] round_filter input=320 output=320
# I0603 19:24:24.458684 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0603 19:24:24.481405 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:24.512045 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0603 19:24:24.512175 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I0603 19:24:24.512227 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I0603 19:24:24.513323 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:24.523869 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:24.524046 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:24.606586 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:24.606724 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:24.751866 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:24.752010 140023962949440 efficientnet_model.py:144] round_filter input=40 output=40
# I0603 19:24:24.907954 140023962949440 efficientnet_model.py:144] round_filter input=40 output=40
# I0603 19:24:24.908106 140023962949440 efficientnet_model.py:144] round_filter input=80 output=80
# I0603 19:24:25.103561 140023962949440 efficientnet_model.py:144] round_filter input=80 output=80
# I0603 19:24:25.103754 140023962949440 efficientnet_model.py:144] round_filter input=112 output=112
# I0603 19:24:25.323676 140023962949440 efficientnet_model.py:144] round_filter input=112 output=112
# I0603 19:24:25.323819 140023962949440 efficientnet_model.py:144] round_filter input=192 output=192
# I0603 19:24:25.584769 140023962949440 efficientnet_model.py:144] round_filter input=192 output=192
# I0603 19:24:25.584923 140023962949440 efficientnet_model.py:144] round_filter input=320 output=320
# I0603 19:24:25.690372 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0603 19:24:25.717798 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:25.750417 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0603 19:24:25.750557 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I0603 19:24:25.750613 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I0603 19:24:25.751649 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:25.763442 140023962949440 efficientnet_model.py:144] round_filter input=32 output=32
# I0603 19:24:25.763589 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:25.854423 140023962949440 efficientnet_model.py:144] round_filter input=16 output=16
# I0603 19:24:25.854562 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:26.015089 140023962949440 efficientnet_model.py:144] round_filter input=24 output=24
# I0603 19:24:26.015251 140023962949440 efficientnet_model.py:144] round_filter input=40 output=48
# I0603 19:24:26.288750 140023962949440 efficientnet_model.py:144] round_filter input=40 output=48
# I0603 19:24:26.288904 140023962949440 efficientnet_model.py:144] round_filter input=80 output=88
# I0603 19:24:26.505281 140023962949440 efficientnet_model.py:144] round_filter input=80 output=88
# I0603 19:24:26.505430 140023962949440 efficientnet_model.py:144] round_filter input=112 output=120
# I0603 19:24:26.713174 140023962949440 efficientnet_model.py:144] round_filter input=112 output=120
# I0603 19:24:26.713319 140023962949440 efficientnet_model.py:144] round_filter input=192 output=208
# I0603 19:24:26.971826 140023962949440 efficientnet_model.py:144] round_filter input=192 output=208
# I0603 19:24:26.971963 140023962949440 efficientnet_model.py:144] round_filter input=320 output=352
# I0603 19:24:27.077415 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=1408
# I0603 19:24:27.099253 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:27.134739 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0603 19:24:27.134908 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0603 19:24:27.134962 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0603 19:24:27.136013 140023962949440 efficientnet_model.py:144] round_filter input=32 output=40
# I0603 19:24:27.150587 140023962949440 efficientnet_model.py:144] round_filter input=32 output=40
# I0603 19:24:27.150717 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:27.231782 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:27.231930 140023962949440 efficientnet_model.py:144] round_filter input=24 output=32
# I0603 19:24:27.380089 140023962949440 efficientnet_model.py:144] round_filter input=24 output=32
# I0603 19:24:27.380222 140023962949440 efficientnet_model.py:144] round_filter input=40 output=48
# I0603 19:24:27.527025 140023962949440 efficientnet_model.py:144] round_filter input=40 output=48
# I0603 19:24:27.527184 140023962949440 efficientnet_model.py:144] round_filter input=80 output=96
# I0603 19:24:27.779567 140023962949440 efficientnet_model.py:144] round_filter input=80 output=96
# I0603 19:24:27.779750 140023962949440 efficientnet_model.py:144] round_filter input=112 output=136
# I0603 19:24:28.096699 140023962949440 efficientnet_model.py:144] round_filter input=112 output=136
# I0603 19:24:28.096871 140023962949440 efficientnet_model.py:144] round_filter input=192 output=232
# I0603 19:24:28.445687 140023962949440 efficientnet_model.py:144] round_filter input=192 output=232
# I0603 19:24:28.445849 140023962949440 efficientnet_model.py:144] round_filter input=320 output=384
# I0603 19:24:28.617601 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=1536
# I0603 19:24:28.637163 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:28.674479 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0603 19:24:28.674616 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I0603 19:24:28.674671 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0603 19:24:28.675611 140023962949440 efficientnet_model.py:144] round_filter input=32 output=48
# I0603 19:24:28.686663 140023962949440 efficientnet_model.py:144] round_filter input=32 output=48
# I0603 19:24:28.686810 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:28.768470 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:28.768860 140023962949440 efficientnet_model.py:144] round_filter input=24 output=32
# I0603 19:24:28.991126 140023962949440 efficientnet_model.py:144] round_filter input=24 output=32
# I0603 19:24:28.991279 140023962949440 efficientnet_model.py:144] round_filter input=40 output=56
# I0603 19:24:29.199246 140023962949440 efficientnet_model.py:144] round_filter input=40 output=56
# I0603 19:24:29.199392 140023962949440 efficientnet_model.py:144] round_filter input=80 output=112
# I0603 19:24:29.673792 140023962949440 efficientnet_model.py:144] round_filter input=80 output=112
# I0603 19:24:29.673928 140023962949440 efficientnet_model.py:144] round_filter input=112 output=160
# I0603 19:24:30.045099 140023962949440 efficientnet_model.py:144] round_filter input=112 output=160
# I0603 19:24:30.045245 140023962949440 efficientnet_model.py:144] round_filter input=192 output=272
# I0603 19:24:30.614414 140023962949440 efficientnet_model.py:144] round_filter input=192 output=272
# I0603 19:24:30.614582 140023962949440 efficientnet_model.py:144] round_filter input=320 output=448
# I0603 19:24:30.747630 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=1792
# I0603 19:24:30.769908 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:30.815284 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0603 19:24:30.815435 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0603 19:24:30.815489 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0603 19:24:30.816648 140023962949440 efficientnet_model.py:144] round_filter input=32 output=48
# I0603 19:24:30.827862 140023962949440 efficientnet_model.py:144] round_filter input=32 output=48
# I0603 19:24:30.828010 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:30.967355 140023962949440 efficientnet_model.py:144] round_filter input=16 output=24
# I0603 19:24:30.967493 140023962949440 efficientnet_model.py:144] round_filter input=24 output=40
# I0603 19:24:31.242452 140023962949440 efficientnet_model.py:144] round_filter input=24 output=40
# I0603 19:24:31.242594 140023962949440 efficientnet_model.py:144] round_filter input=40 output=64
# I0603 19:24:31.505706 140023962949440 efficientnet_model.py:144] round_filter input=40 output=64
# I0603 19:24:31.505844 140023962949440 efficientnet_model.py:144] round_filter input=80 output=128
# I0603 19:24:31.875429 140023962949440 efficientnet_model.py:144] round_filter input=80 output=128
# I0603 19:24:31.875577 140023962949440 efficientnet_model.py:144] round_filter input=112 output=176
# I0603 19:24:32.252257 140023962949440 efficientnet_model.py:144] round_filter input=112 output=176
# I0603 19:24:32.252405 140023962949440 efficientnet_model.py:144] round_filter input=192 output=304
# I0603 19:24:32.710537 140023962949440 efficientnet_model.py:144] round_filter input=192 output=304
# I0603 19:24:32.710676 140023962949440 efficientnet_model.py:144] round_filter input=320 output=512
# I0603 19:24:33.008153 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=2048
# I0603 19:24:33.028717 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:33.080596 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0603 19:24:33.080744 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0603 19:24:33.080797 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0603 19:24:33.081777 140023962949440 efficientnet_model.py:144] round_filter input=32 output=56
# I0603 19:24:33.096858 140023962949440 efficientnet_model.py:144] round_filter input=32 output=56
# I0603 19:24:33.097006 140023962949440 efficientnet_model.py:144] round_filter input=16 output=32
# I0603 19:24:33.236548 140023962949440 efficientnet_model.py:144] round_filter input=16 output=32
# I0603 19:24:33.236713 140023962949440 efficientnet_model.py:144] round_filter input=24 output=40
# I0603 19:24:33.593157 140023962949440 efficientnet_model.py:144] round_filter input=24 output=40
# I0603 19:24:33.593304 140023962949440 efficientnet_model.py:144] round_filter input=40 output=72
# I0603 19:24:33.917438 140023962949440 efficientnet_model.py:144] round_filter input=40 output=72
# I0603 19:24:33.917580 140023962949440 efficientnet_model.py:144] round_filter input=80 output=144
# I0603 19:24:34.322547 140023962949440 efficientnet_model.py:144] round_filter input=80 output=144
# I0603 19:24:34.322688 140023962949440 efficientnet_model.py:144] round_filter input=112 output=200
# I0603 19:24:34.722291 140023962949440 efficientnet_model.py:144] round_filter input=112 output=200
# I0603 19:24:34.722476 140023962949440 efficientnet_model.py:144] round_filter input=192 output=344
# I0603 19:24:35.276187 140023962949440 efficientnet_model.py:144] round_filter input=192 output=344
# I0603 19:24:35.276343 140023962949440 efficientnet_model.py:144] round_filter input=320 output=576
# I0603 19:24:35.438702 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0603 19:24:35.456508 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0603 19:24:35.511896 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0603 19:24:35.512040 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0603 19:24:35.512098 140023962949440 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0603 19:24:35.513031 140023962949440 efficientnet_model.py:144] round_filter input=32 output=64
# I0603 19:24:35.526454 140023962949440 efficientnet_model.py:144] round_filter input=32 output=64
# I0603 19:24:35.526591 140023962949440 efficientnet_model.py:144] round_filter input=16 output=32
# I0603 19:24:35.690236 140023962949440 efficientnet_model.py:144] round_filter input=16 output=32
# I0603 19:24:35.690391 140023962949440 efficientnet_model.py:144] round_filter input=24 output=48
# I0603 19:24:36.030994 140023962949440 efficientnet_model.py:144] round_filter input=24 output=48
# I0603 19:24:36.031166 140023962949440 efficientnet_model.py:144] round_filter input=40 output=80
# I0603 19:24:36.597952 140023962949440 efficientnet_model.py:144] round_filter input=40 output=80
# I0603 19:24:36.598089 140023962949440 efficientnet_model.py:144] round_filter input=80 output=160
# I0603 19:24:37.147204 140023962949440 efficientnet_model.py:144] round_filter input=80 output=160
# I0603 19:24:37.147369 140023962949440 efficientnet_model.py:144] round_filter input=112 output=224
# I0603 19:24:37.728031 140023962949440 efficientnet_model.py:144] round_filter input=112 output=224
# I0603 19:24:37.728199 140023962949440 efficientnet_model.py:144] round_filter input=192 output=384
# I0603 19:24:38.471071 140023962949440 efficientnet_model.py:144] round_filter input=192 output=384
# I0603 19:24:38.471256 140023962949440 efficientnet_model.py:144] round_filter input=320 output=640
# I0603 19:24:38.697800 140023962949440 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0603 19:24:38.723976 140023962949440 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.41s
# I0603 19:24:38.805143 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.41s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# I0603 19:24:38.814993 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0603 19:24:38.816155 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0603 19:24:38.816480 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0603 19:24:38.817298 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0603 19:24:38.818066 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0603 19:24:38.818352 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0603 19:24:38.819200 140023962949440 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 19.152s
#
# OK (skipped=1)

# %% [markdown]
# # 3.&nbsp;Preprocessing Data

# %% [markdown]
# We performed data preprocessing using the [Roboflow](https://roboflow.com/) platform.

# %% [markdown]
# ## 3.1&nbsp;Uploading Data and Splitting Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.2&nbsp;Resizing and Augmenting Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.3&nbsp;Download the Data and Convert to TFRecord

# %%
# Install Roboflow library to download the dataset
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.0.9-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 1.1 MB/s eta 0:00:01
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in ./venv/lib/python3.8/site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: python-dateutil in ./venv/lib/python3.8/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: PyYAML>=5.3.1 in ./venv/lib/python3.8/site-packages (from roboflow) (5.4.1)
# Requirement already satisfied: tqdm>=4.41.0 in ./venv/lib/python3.8/site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: opencv-python>=4.1.2 in ./venv/lib/python3.8/site-packages (from roboflow) (4.7.0.72)
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 3.4 MB/s eta 0:00:01
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: numpy>=1.18.5 in ./venv/lib/python3.8/site-packages (from roboflow) (1.24.3)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: Pillow>=7.1.2 in ./venv/lib/python3.8/site-packages (from roboflow) (9.5.0)
# Collecting certifi==2022.12.7
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./venv/lib/python3.8/site-packages (from roboflow) (1.26.16)
# Requirement already satisfied: pyparsing==2.4.7 in ./venv/lib/python3.8/site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.8/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from matplotlib->roboflow) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.8/site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.8/site-packages (from matplotlib->roboflow) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.8/site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests->roboflow) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->roboflow) (3.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9682 sha256=99e3a94e5a09d8192ab6109859262ee91f526867bde268dbc86bcb8fd7d2748a
#   Stored in directory: /home/dadang/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: requests-toolbelt, chardet, python-dotenv, wget, idna, cycler, certifi, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.5.7
#     Uninstalling certifi-2023.5.7:
#       Successfully uninstalled certifi-2023.5.7
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.0.9 wget-3.2

# %%
# install the dotenv to get the key
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.8/site-packages (1.0.0)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key=os.getenv("api_key_squidmaster")

# %%
# Download the dataset
from roboflow import Roboflow
rf = Roboflow(api_key=api_key, model_format="tfrecord")
dataset = rf.workspace().project("patuli-numbers-dataset").version(1).download(location="dataset")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format tfrecord in progress : 85.0%
# Version export complete for tfrecord format
# Downloading Dataset Version Zip in dataset to tfrecord: 100% [49673752 / 49673752] bytes
# Extracting Dataset Version Zip to dataset in tfrecord:: 100%|██████████| 11/11 [00:00<00:00, 152.02it/s]

# %%
train_record_fname = 'dataset/train/sign-language.tfrecord'
val_record_fname = 'dataset/valid/sign-language.tfrecord'
label_map_pbtxt_fname = 'dataset/train/sign-language_label_map.pbtxt'

# %% [markdown]
# # 4.&nbsp;Setup Training

# %%
#Models available in the TF2 object detection zoo
chosen_model = 'ssd-mobilenet-v2-fpnlite-320'

MODELS_CONFIG = {
      'ssd-mobilenet-v2-fpnlite-320': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz',
    }
}

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']

# %%
# Create "mymodel" folder for holding pre-trained weights and configuration files
# %mkdir models/config/
# %cd models/config/

# Download pre-trained model weights
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

# Download training configuration file for model
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}

# %cd ../..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/models/config
# --2023-06-03 19:34:35--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.4.128, 2404:6800:4003:c04::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.4.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  4.17MB/s    in 5.6s
#
# 2023-06-03 19:34:41 (3.51 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# --2023-06-03 19:34:41--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4684 (4.6K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’
#
# ssd_mobilenet_v2_fp 100%[===================>]   4.57K  --.-KB/s    in 0.002s
#
# 2023-06-03 19:34:41 (2.36 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’ saved [4684/4684]
#
# /home/dadang/Documents/ML/Bangkit/train_huruf

# %%
# Set training parameters for the model
num_steps = 50000
batch_size = 8

# %%
# Set file locations and get number of classes for config file
pipeline_fname = 'models/config/' + base_pipeline_file
fine_tune_checkpoint = 'models/config/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)
print('Total classes:', num_classes)
# Out:
# Total classes: 11

# %%
# Create custom configuration file by writing the dataset, model checkpoint, and training parameters into the base pipeline file
import re

print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()

with open('models/config/pipeline_file.config', 'w') as f:
    
    # Set fine_tune_checkpoint path
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # Set tfrecord files for train and test datasets
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    # Set label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set batch_size
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    # Change fine-tune checkpoint type from "classification" to "detection"
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)
    
    # Reduce learning rate (because it's too high in the default config file)
    s = re.sub('learning_rate_base: .8',
               'learning_rate_base: .08', s)
      
    s = re.sub('warmup_learning_rate: 0.13333',
               'warmup_learning_rate: .026666', s)

    f.write(s)
# Out:
# writing custom configuration file

# %%
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = 'models/config/pipeline_file.config'
model_dir = 'training/'

# %% [markdown]
# # 5.&nbsp;Start Training

# %%
# Run training!
# !python3 models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2023-06-03 19:34:58.325765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.331576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.331807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.332283: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 19:34:58.333296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.333548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.333758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.896059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.896369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.896401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 19:34:58.896635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 19:34:58.896713: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0603 19:34:59.522940 140087170545472 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 50000
# I0603 19:34:59.525784 140087170545472 config_util.py:552] Maybe overwriting train_steps: 50000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0603 19:34:59.526004 140087170545472 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0603 19:34:59.627297 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['dataset/train/sign-language.tfrecord']
# I0603 19:34:59.632827 140087170545472 dataset_builder.py:162] Reading unweighted datasets: ['dataset/train/sign-language.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['dataset/train/sign-language.tfrecord']
# I0603 19:34:59.633089 140087170545472 dataset_builder.py:79] Reading record datasets for input file: ['dataset/train/sign-language.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0603 19:34:59.633178 140087170545472 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0603 19:34:59.633236 140087170545472 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0603 19:34:59.636245 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0603 19:34:59.657403 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0603 19:35:03.022398 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0603 19:35:04.545991 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0603 19:35:05.391841 140087170545472 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0603 19:35:09.870707 140080492574464 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0603 19:35:16.309320 140080492574464 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-03 19:35:21.225527: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2023-06-03 19:35:22.573029: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-03 19:35:22.577718: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-06-03 19:35:22.577756: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at /usr/local/cuda-11.2/bin/ptxas
# 2023-06-03 19:35:22.577830: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: /usr/local/cuda-11.2/bin/ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-06-03 19:35:23.630593: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.653522 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.655087 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.657360 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.657964 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.659230 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.659776 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.661157 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.661850 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.663511 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0603 19:35:24.664069 140087170545472 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0603 19:35:25.016480 140080962336512 deprecation.py:541] From /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0603 19:35:25.565635 140080962336512 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0603 19:35:30.285172 140080962336512 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0603 19:35:34.525644 140080962336512 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0603 19:35:39.088060 140080962336512 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.403s
# I0603 19:36:05.176798 140087170545472 model_lib_v2.py:705] Step 100 per-step time 0.403s
# INFO:tensorflow:{'Loss/classification_loss': 0.5781739,
#  'Loss/localization_loss': 0.28051987,
#  'Loss/regularization_loss': 0.15366057,
#  'Loss/total_loss': 1.0123543,
#  'learning_rate': 0.0319994}
# I0603 19:36:05.177015 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.5781739,
#  'Loss/localization_loss': 0.28051987,
#  'Loss/regularization_loss': 0.15366057,
#  'Loss/total_loss': 1.0123543,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.181s
# I0603 19:36:23.234594 140087170545472 model_lib_v2.py:705] Step 200 per-step time 0.181s
# INFO:tensorflow:{'Loss/classification_loss': 0.38349158,
#  'Loss/localization_loss': 0.089701265,
#  'Loss/regularization_loss': 0.15356532,
#  'Loss/total_loss': 0.62675816,
#  'learning_rate': 0.0373328}
# I0603 19:36:23.234817 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.38349158,
#  'Loss/localization_loss': 0.089701265,
#  'Loss/regularization_loss': 0.15356532,
#  'Loss/total_loss': 0.62675816,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.127s
# I0603 19:36:35.966560 140087170545472 model_lib_v2.py:705] Step 300 per-step time 0.127s
# INFO:tensorflow:{'Loss/classification_loss': 0.35859194,
#  'Loss/localization_loss': 0.07653313,
#  'Loss/regularization_loss': 0.15334685,
#  'Loss/total_loss': 0.58847195,
#  'learning_rate': 0.0426662}
# I0603 19:36:35.966816 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.35859194,
#  'Loss/localization_loss': 0.07653313,
#  'Loss/regularization_loss': 0.15334685,
#  'Loss/total_loss': 0.58847195,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.186s
# I0603 19:36:54.598299 140087170545472 model_lib_v2.py:705] Step 400 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.34071586,
#  'Loss/localization_loss': 0.07176621,
#  'Loss/regularization_loss': 0.15299271,
#  'Loss/total_loss': 0.5654748,
#  'learning_rate': 0.047999598}
# I0603 19:36:54.598518 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.34071586,
#  'Loss/localization_loss': 0.07176621,
#  'Loss/regularization_loss': 0.15299271,
#  'Loss/total_loss': 0.5654748,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.122s
# I0603 19:37:06.798873 140087170545472 model_lib_v2.py:705] Step 500 per-step time 0.122s
# INFO:tensorflow:{'Loss/classification_loss': 0.31337434,
#  'Loss/localization_loss': 0.09769653,
#  'Loss/regularization_loss': 0.15257885,
#  'Loss/total_loss': 0.5636497,
#  'learning_rate': 0.053333}
# I0603 19:37:06.799079 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.31337434,
#  'Loss/localization_loss': 0.09769653,
#  'Loss/regularization_loss': 0.15257885,
#  'Loss/total_loss': 0.5636497,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.115s
# I0603 19:37:18.295609 140087170545472 model_lib_v2.py:705] Step 600 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.3686607,
#  'Loss/localization_loss': 0.08924955,
#  'Loss/regularization_loss': 0.15211275,
#  'Loss/total_loss': 0.610023,
#  'learning_rate': 0.0586664}
# I0603 19:37:18.296112 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.3686607,
#  'Loss/localization_loss': 0.08924955,
#  'Loss/regularization_loss': 0.15211275,
#  'Loss/total_loss': 0.610023,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.116s
# I0603 19:37:29.881295 140087170545472 model_lib_v2.py:705] Step 700 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.26634604,
#  'Loss/localization_loss': 0.104081966,
#  'Loss/regularization_loss': 0.15168256,
#  'Loss/total_loss': 0.5221106,
#  'learning_rate': 0.0639998}
# I0603 19:37:29.881606 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.26634604,
#  'Loss/localization_loss': 0.104081966,
#  'Loss/regularization_loss': 0.15168256,
#  'Loss/total_loss': 0.5221106,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.115s
# I0603 19:37:41.334916 140087170545472 model_lib_v2.py:705] Step 800 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.2554794,
#  'Loss/localization_loss': 0.04789111,
#  'Loss/regularization_loss': 0.15131776,
#  'Loss/total_loss': 0.45468825,
#  'learning_rate': 0.069333196}
# I0603 19:37:41.335233 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.2554794,
#  'Loss/localization_loss': 0.04789111,
#  'Loss/regularization_loss': 0.15131776,
#  'Loss/total_loss': 0.45468825,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.126s
# I0603 19:37:53.897639 140087170545472 model_lib_v2.py:705] Step 900 per-step time 0.126s
# INFO:tensorflow:{'Loss/classification_loss': 0.26785868,
#  'Loss/localization_loss': 0.050581098,
#  'Loss/regularization_loss': 0.15093035,
#  'Loss/total_loss': 0.46937013,
#  'learning_rate': 0.074666604}
# I0603 19:37:53.897844 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.26785868,
#  'Loss/localization_loss': 0.050581098,
#  'Loss/regularization_loss': 0.15093035,
#  'Loss/total_loss': 0.46937013,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.116s
# I0603 19:38:05.475429 140087170545472 model_lib_v2.py:705] Step 1000 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.32315007,
#  'Loss/localization_loss': 0.05439319,
#  'Loss/regularization_loss': 0.15058453,
#  'Loss/total_loss': 0.5281278,
#  'learning_rate': 0.08}
# I0603 19:38:05.475629 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.32315007,
#  'Loss/localization_loss': 0.05439319,
#  'Loss/regularization_loss': 0.15058453,
#  'Loss/total_loss': 0.5281278,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.115s
# I0603 19:38:17.025040 140087170545472 model_lib_v2.py:705] Step 1100 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.29316077,
#  'Loss/localization_loss': 0.06364872,
#  'Loss/regularization_loss': 0.150165,
#  'Loss/total_loss': 0.5069745,
#  'learning_rate': 0.07999918}
# I0603 19:38:17.025337 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.29316077,
#  'Loss/localization_loss': 0.06364872,
#  'Loss/regularization_loss': 0.150165,
#  'Loss/total_loss': 0.5069745,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.113s
# I0603 19:38:28.307910 140087170545472 model_lib_v2.py:705] Step 1200 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.19344956,
#  'Loss/localization_loss': 0.07134358,
#  'Loss/regularization_loss': 0.14963931,
#  'Loss/total_loss': 0.41443244,
#  'learning_rate': 0.079996705}
# I0603 19:38:28.308132 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.19344956,
#  'Loss/localization_loss': 0.07134358,
#  'Loss/regularization_loss': 0.14963931,
#  'Loss/total_loss': 0.41443244,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.116s
# I0603 19:38:39.883673 140087170545472 model_lib_v2.py:705] Step 1300 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.25848094,
#  'Loss/localization_loss': 0.04163998,
#  'Loss/regularization_loss': 0.14929993,
#  'Loss/total_loss': 0.44942087,
#  'learning_rate': 0.0799926}
# I0603 19:38:39.883900 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.25848094,
#  'Loss/localization_loss': 0.04163998,
#  'Loss/regularization_loss': 0.14929993,
#  'Loss/total_loss': 0.44942087,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.113s
# I0603 19:38:51.146555 140087170545472 model_lib_v2.py:705] Step 1400 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.2259238,
#  'Loss/localization_loss': 0.045053255,
#  'Loss/regularization_loss': 0.14918107,
#  'Loss/total_loss': 0.42015812,
#  'learning_rate': 0.07998685}
# I0603 19:38:51.146773 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.2259238,
#  'Loss/localization_loss': 0.045053255,
#  'Loss/regularization_loss': 0.14918107,
#  'Loss/total_loss': 0.42015812,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.113s
# I0603 19:39:02.485729 140087170545472 model_lib_v2.py:705] Step 1500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.16053697,
#  'Loss/localization_loss': 0.03386167,
#  'Loss/regularization_loss': 0.1488614,
#  'Loss/total_loss': 0.34326005,
#  'learning_rate': 0.07997945}
# I0603 19:39:02.485949 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.16053697,
#  'Loss/localization_loss': 0.03386167,
#  'Loss/regularization_loss': 0.1488614,
#  'Loss/total_loss': 0.34326005,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.114s
# I0603 19:39:13.875028 140087170545472 model_lib_v2.py:705] Step 1600 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.15836938,
#  'Loss/localization_loss': 0.0362449,
#  'Loss/regularization_loss': 0.14862958,
#  'Loss/total_loss': 0.34324384,
#  'learning_rate': 0.079970405}
# I0603 19:39:13.875229 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.15836938,
#  'Loss/localization_loss': 0.0362449,
#  'Loss/regularization_loss': 0.14862958,
#  'Loss/total_loss': 0.34324384,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.114s
# I0603 19:39:25.275194 140087170545472 model_lib_v2.py:705] Step 1700 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.15643312,
#  'Loss/localization_loss': 0.04405692,
#  'Loss/regularization_loss': 0.14824344,
#  'Loss/total_loss': 0.34873348,
#  'learning_rate': 0.07995972}
# I0603 19:39:25.275389 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.15643312,
#  'Loss/localization_loss': 0.04405692,
#  'Loss/regularization_loss': 0.14824344,
#  'Loss/total_loss': 0.34873348,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.114s
# I0603 19:39:36.649833 140087170545472 model_lib_v2.py:705] Step 1800 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.1713455,
#  'Loss/localization_loss': 0.040421024,
#  'Loss/regularization_loss': 0.14787085,
#  'Loss/total_loss': 0.35963738,
#  'learning_rate': 0.0799474}
# I0603 19:39:36.650062 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.1713455,
#  'Loss/localization_loss': 0.040421024,
#  'Loss/regularization_loss': 0.14787085,
#  'Loss/total_loss': 0.35963738,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.114s
# I0603 19:39:48.061838 140087170545472 model_lib_v2.py:705] Step 1900 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.18218258,
#  'Loss/localization_loss': 0.054369528,
#  'Loss/regularization_loss': 0.14733808,
#  'Loss/total_loss': 0.38389018,
#  'learning_rate': 0.07993342}
# I0603 19:39:48.062038 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.18218258,
#  'Loss/localization_loss': 0.054369528,
#  'Loss/regularization_loss': 0.14733808,
#  'Loss/total_loss': 0.38389018,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.114s
# I0603 19:39:59.490068 140087170545472 model_lib_v2.py:705] Step 2000 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.13965459,
#  'Loss/localization_loss': 0.043820012,
#  'Loss/regularization_loss': 0.14691044,
#  'Loss/total_loss': 0.33038503,
#  'learning_rate': 0.07991781}
# I0603 19:39:59.490266 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.13965459,
#  'Loss/localization_loss': 0.043820012,
#  'Loss/regularization_loss': 0.14691044,
#  'Loss/total_loss': 0.33038503,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.117s
# I0603 19:40:11.178226 140087170545472 model_lib_v2.py:705] Step 2100 per-step time 0.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.19955304,
#  'Loss/localization_loss': 0.050327998,
#  'Loss/regularization_loss': 0.14657778,
#  'Loss/total_loss': 0.3964588,
#  'learning_rate': 0.07990056}
# I0603 19:40:11.178438 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.19955304,
#  'Loss/localization_loss': 0.050327998,
#  'Loss/regularization_loss': 0.14657778,
#  'Loss/total_loss': 0.3964588,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.114s
# I0603 19:40:22.599727 140087170545472 model_lib_v2.py:705] Step 2200 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.16772193,
#  'Loss/localization_loss': 0.036029227,
#  'Loss/regularization_loss': 0.14622365,
#  'Loss/total_loss': 0.3499748,
#  'learning_rate': 0.07988167}
# I0603 19:40:22.600047 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.16772193,
#  'Loss/localization_loss': 0.036029227,
#  'Loss/regularization_loss': 0.14622365,
#  'Loss/total_loss': 0.3499748,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.114s
# I0603 19:40:33.990643 140087170545472 model_lib_v2.py:705] Step 2300 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.19600168,
#  'Loss/localization_loss': 0.040411144,
#  'Loss/regularization_loss': 0.14595793,
#  'Loss/total_loss': 0.38237077,
#  'learning_rate': 0.07986114}
# I0603 19:40:33.990863 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.19600168,
#  'Loss/localization_loss': 0.040411144,
#  'Loss/regularization_loss': 0.14595793,
#  'Loss/total_loss': 0.38237077,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.114s
# I0603 19:40:45.381248 140087170545472 model_lib_v2.py:705] Step 2400 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.11157558,
#  'Loss/localization_loss': 0.032239556,
#  'Loss/regularization_loss': 0.1455104,
#  'Loss/total_loss': 0.28932554,
#  'learning_rate': 0.07983897}
# I0603 19:40:45.381450 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11157558,
#  'Loss/localization_loss': 0.032239556,
#  'Loss/regularization_loss': 0.1455104,
#  'Loss/total_loss': 0.28932554,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.113s
# I0603 19:40:56.631656 140087170545472 model_lib_v2.py:705] Step 2500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.13876678,
#  'Loss/localization_loss': 0.049982555,
#  'Loss/regularization_loss': 0.14513268,
#  'Loss/total_loss': 0.33388203,
#  'learning_rate': 0.079815164}
# I0603 19:40:56.631874 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.13876678,
#  'Loss/localization_loss': 0.049982555,
#  'Loss/regularization_loss': 0.14513268,
#  'Loss/total_loss': 0.33388203,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.113s
# I0603 19:41:07.896585 140087170545472 model_lib_v2.py:705] Step 2600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.11787191,
#  'Loss/localization_loss': 0.024257636,
#  'Loss/regularization_loss': 0.14471853,
#  'Loss/total_loss': 0.28684807,
#  'learning_rate': 0.07978972}
# I0603 19:41:07.896787 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11787191,
#  'Loss/localization_loss': 0.024257636,
#  'Loss/regularization_loss': 0.14471853,
#  'Loss/total_loss': 0.28684807,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.113s
# I0603 19:41:19.207107 140087170545472 model_lib_v2.py:705] Step 2700 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.15947683,
#  'Loss/localization_loss': 0.030085092,
#  'Loss/regularization_loss': 0.14441748,
#  'Loss/total_loss': 0.3339794,
#  'learning_rate': 0.07976264}
# I0603 19:41:19.207324 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.15947683,
#  'Loss/localization_loss': 0.030085092,
#  'Loss/regularization_loss': 0.14441748,
#  'Loss/total_loss': 0.3339794,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.115s
# I0603 19:41:30.674400 140087170545472 model_lib_v2.py:705] Step 2800 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.22108069,
#  'Loss/localization_loss': 0.026260763,
#  'Loss/regularization_loss': 0.14422072,
#  'Loss/total_loss': 0.39156216,
#  'learning_rate': 0.07973392}
# I0603 19:41:30.674604 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.22108069,
#  'Loss/localization_loss': 0.026260763,
#  'Loss/regularization_loss': 0.14422072,
#  'Loss/total_loss': 0.39156216,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.114s
# I0603 19:41:42.044965 140087170545472 model_lib_v2.py:705] Step 2900 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.11797395,
#  'Loss/localization_loss': 0.035662897,
#  'Loss/regularization_loss': 0.14392304,
#  'Loss/total_loss': 0.2975599,
#  'learning_rate': 0.07970358}
# I0603 19:41:42.045209 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11797395,
#  'Loss/localization_loss': 0.035662897,
#  'Loss/regularization_loss': 0.14392304,
#  'Loss/total_loss': 0.2975599,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.115s
# I0603 19:41:53.524408 140087170545472 model_lib_v2.py:705] Step 3000 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.113997236,
#  'Loss/localization_loss': 0.0377971,
#  'Loss/regularization_loss': 0.14336772,
#  'Loss/total_loss': 0.29516208,
#  'learning_rate': 0.0796716}
# I0603 19:41:53.524607 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.113997236,
#  'Loss/localization_loss': 0.0377971,
#  'Loss/regularization_loss': 0.14336772,
#  'Loss/total_loss': 0.29516208,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.117s
# I0603 19:42:05.179543 140087170545472 model_lib_v2.py:705] Step 3100 per-step time 0.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.11099427,
#  'Loss/localization_loss': 0.037571754,
#  'Loss/regularization_loss': 0.14277865,
#  'Loss/total_loss': 0.29134467,
#  'learning_rate': 0.07963799}
# I0603 19:42:05.179744 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11099427,
#  'Loss/localization_loss': 0.037571754,
#  'Loss/regularization_loss': 0.14277865,
#  'Loss/total_loss': 0.29134467,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.114s
# I0603 19:42:16.561809 140087170545472 model_lib_v2.py:705] Step 3200 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.11894576,
#  'Loss/localization_loss': 0.035558686,
#  'Loss/regularization_loss': 0.14259344,
#  'Loss/total_loss': 0.2970979,
#  'learning_rate': 0.07960275}
# I0603 19:42:16.562174 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11894576,
#  'Loss/localization_loss': 0.035558686,
#  'Loss/regularization_loss': 0.14259344,
#  'Loss/total_loss': 0.2970979,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.115s
# I0603 19:42:28.037781 140087170545472 model_lib_v2.py:705] Step 3300 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.1118079,
#  'Loss/localization_loss': 0.036233213,
#  'Loss/regularization_loss': 0.14214925,
#  'Loss/total_loss': 0.29019037,
#  'learning_rate': 0.07956588}
# I0603 19:42:28.037988 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.1118079,
#  'Loss/localization_loss': 0.036233213,
#  'Loss/regularization_loss': 0.14214925,
#  'Loss/total_loss': 0.29019037,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.114s
# I0603 19:42:39.413879 140087170545472 model_lib_v2.py:705] Step 3400 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.10079775,
#  'Loss/localization_loss': 0.021038806,
#  'Loss/regularization_loss': 0.14164165,
#  'Loss/total_loss': 0.26347822,
#  'learning_rate': 0.079527386}
# I0603 19:42:39.414088 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.10079775,
#  'Loss/localization_loss': 0.021038806,
#  'Loss/regularization_loss': 0.14164165,
#  'Loss/total_loss': 0.26347822,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.114s
# I0603 19:42:50.853014 140087170545472 model_lib_v2.py:705] Step 3500 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.074529305,
#  'Loss/localization_loss': 0.03178389,
#  'Loss/regularization_loss': 0.14112945,
#  'Loss/total_loss': 0.24744265,
#  'learning_rate': 0.07948727}
# I0603 19:42:50.853224 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.074529305,
#  'Loss/localization_loss': 0.03178389,
#  'Loss/regularization_loss': 0.14112945,
#  'Loss/total_loss': 0.24744265,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.113s
# I0603 19:43:02.167101 140087170545472 model_lib_v2.py:705] Step 3600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.097401954,
#  'Loss/localization_loss': 0.034942735,
#  'Loss/regularization_loss': 0.1408772,
#  'Loss/total_loss': 0.2732219,
#  'learning_rate': 0.079445526}
# I0603 19:43:02.167321 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.097401954,
#  'Loss/localization_loss': 0.034942735,
#  'Loss/regularization_loss': 0.1408772,
#  'Loss/total_loss': 0.2732219,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.115s
# I0603 19:43:13.641399 140087170545472 model_lib_v2.py:705] Step 3700 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.07226947,
#  'Loss/localization_loss': 0.016598407,
#  'Loss/regularization_loss': 0.1405115,
#  'Loss/total_loss': 0.22937937,
#  'learning_rate': 0.07940216}
# I0603 19:43:13.641597 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.07226947,
#  'Loss/localization_loss': 0.016598407,
#  'Loss/regularization_loss': 0.1405115,
#  'Loss/total_loss': 0.22937937,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.113s
# I0603 19:43:24.920657 140087170545472 model_lib_v2.py:705] Step 3800 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.07438366,
#  'Loss/localization_loss': 0.02500343,
#  'Loss/regularization_loss': 0.13988933,
#  'Loss/total_loss': 0.23927642,
#  'learning_rate': 0.079357184}
# I0603 19:43:24.920861 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.07438366,
#  'Loss/localization_loss': 0.02500343,
#  'Loss/regularization_loss': 0.13988933,
#  'Loss/total_loss': 0.23927642,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.115s
# I0603 19:43:36.374925 140087170545472 model_lib_v2.py:705] Step 3900 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.11342998,
#  'Loss/localization_loss': 0.017056106,
#  'Loss/regularization_loss': 0.13962667,
#  'Loss/total_loss': 0.27011275,
#  'learning_rate': 0.07931058}
# I0603 19:43:36.375135 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.11342998,
#  'Loss/localization_loss': 0.017056106,
#  'Loss/regularization_loss': 0.13962667,
#  'Loss/total_loss': 0.27011275,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.114s
# I0603 19:43:47.738372 140087170545472 model_lib_v2.py:705] Step 4000 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.07523893,
#  'Loss/localization_loss': 0.01876281,
#  'Loss/regularization_loss': 0.13918406,
#  'Loss/total_loss': 0.2331858,
#  'learning_rate': 0.07926236}
# I0603 19:43:47.738556 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.07523893,
#  'Loss/localization_loss': 0.01876281,
#  'Loss/regularization_loss': 0.13918406,
#  'Loss/total_loss': 0.2331858,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.117s
# I0603 19:43:59.417652 140087170545472 model_lib_v2.py:705] Step 4100 per-step time 0.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.05942004,
#  'Loss/localization_loss': 0.017140804,
#  'Loss/regularization_loss': 0.13857836,
#  'Loss/total_loss': 0.21513921,
#  'learning_rate': 0.07921253}
# I0603 19:43:59.417858 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.05942004,
#  'Loss/localization_loss': 0.017140804,
#  'Loss/regularization_loss': 0.13857836,
#  'Loss/total_loss': 0.21513921,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.114s
# I0603 19:44:10.833922 140087170545472 model_lib_v2.py:705] Step 4200 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.09328283,
#  'Loss/localization_loss': 0.016902722,
#  'Loss/regularization_loss': 0.13843302,
#  'Loss/total_loss': 0.24861857,
#  'learning_rate': 0.07916109}
# I0603 19:44:10.834128 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.09328283,
#  'Loss/localization_loss': 0.016902722,
#  'Loss/regularization_loss': 0.13843302,
#  'Loss/total_loss': 0.24861857,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.111s
# I0603 19:44:21.941794 140087170545472 model_lib_v2.py:705] Step 4300 per-step time 0.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.1249347,
#  'Loss/localization_loss': 0.043865684,
#  'Loss/regularization_loss': 0.13816032,
#  'Loss/total_loss': 0.3069607,
#  'learning_rate': 0.07910804}
# I0603 19:44:21.941996 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.1249347,
#  'Loss/localization_loss': 0.043865684,
#  'Loss/regularization_loss': 0.13816032,
#  'Loss/total_loss': 0.3069607,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.112s
# I0603 19:44:33.180582 140087170545472 model_lib_v2.py:705] Step 4400 per-step time 0.112s
# INFO:tensorflow:{'Loss/classification_loss': 0.14211322,
#  'Loss/localization_loss': 0.031766534,
#  'Loss/regularization_loss': 0.13819796,
#  'Loss/total_loss': 0.3120777,
#  'learning_rate': 0.07905338}
# I0603 19:44:33.180788 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.14211322,
#  'Loss/localization_loss': 0.031766534,
#  'Loss/regularization_loss': 0.13819796,
#  'Loss/total_loss': 0.3120777,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.113s
# I0603 19:44:44.503129 140087170545472 model_lib_v2.py:705] Step 4500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.070955016,
#  'Loss/localization_loss': 0.019018501,
#  'Loss/regularization_loss': 0.13773283,
#  'Loss/total_loss': 0.22770634,
#  'learning_rate': 0.07899711}
# I0603 19:44:44.503329 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.070955016,
#  'Loss/localization_loss': 0.019018501,
#  'Loss/regularization_loss': 0.13773283,
#  'Loss/total_loss': 0.22770634,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.115s
# I0603 19:44:55.964629 140087170545472 model_lib_v2.py:705] Step 4600 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.1822273,
#  'Loss/localization_loss': 0.019666284,
#  'Loss/regularization_loss': 0.1373022,
#  'Loss/total_loss': 0.3391958,
#  'learning_rate': 0.078939244}
# I0603 19:44:55.964827 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.1822273,
#  'Loss/localization_loss': 0.019666284,
#  'Loss/regularization_loss': 0.1373022,
#  'Loss/total_loss': 0.3391958,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.113s
# I0603 19:45:07.232716 140087170545472 model_lib_v2.py:705] Step 4700 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.0940683,
#  'Loss/localization_loss': 0.025520034,
#  'Loss/regularization_loss': 0.13674775,
#  'Loss/total_loss': 0.2563361,
#  'learning_rate': 0.07887978}
# I0603 19:45:07.232928 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.0940683,
#  'Loss/localization_loss': 0.025520034,
#  'Loss/regularization_loss': 0.13674775,
#  'Loss/total_loss': 0.2563361,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.113s
# I0603 19:45:18.532121 140087170545472 model_lib_v2.py:705] Step 4800 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.055047102,
#  'Loss/localization_loss': 0.017161094,
#  'Loss/regularization_loss': 0.13628735,
#  'Loss/total_loss': 0.20849554,
#  'learning_rate': 0.07881871}
# I0603 19:45:18.532320 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.055047102,
#  'Loss/localization_loss': 0.017161094,
#  'Loss/regularization_loss': 0.13628735,
#  'Loss/total_loss': 0.20849554,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.114s
# I0603 19:45:29.946316 140087170545472 model_lib_v2.py:705] Step 4900 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.07585578,
#  'Loss/localization_loss': 0.026588276,
#  'Loss/regularization_loss': 0.1358727,
#  'Loss/total_loss': 0.23831676,
#  'learning_rate': 0.07875605}
# I0603 19:45:29.946555 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.07585578,
#  'Loss/localization_loss': 0.026588276,
#  'Loss/regularization_loss': 0.1358727,
#  'Loss/total_loss': 0.23831676,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.113s
# I0603 19:45:41.264347 140087170545472 model_lib_v2.py:705] Step 5000 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.05514264,
#  'Loss/localization_loss': 0.01648756,
#  'Loss/regularization_loss': 0.13534737,
#  'Loss/total_loss': 0.20697758,
#  'learning_rate': 0.078691795}
# I0603 19:45:41.264547 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.05514264,
#  'Loss/localization_loss': 0.01648756,
#  'Loss/regularization_loss': 0.13534737,
#  'Loss/total_loss': 0.20697758,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.121s
# I0603 19:45:53.332355 140087170545472 model_lib_v2.py:705] Step 5100 per-step time 0.121s
# INFO:tensorflow:{'Loss/classification_loss': 0.08380192,
#  'Loss/localization_loss': 0.014970974,
#  'Loss/regularization_loss': 0.13482672,
#  'Loss/total_loss': 0.2335996,
#  'learning_rate': 0.07862595}
# I0603 19:45:53.332554 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.08380192,
#  'Loss/localization_loss': 0.014970974,
#  'Loss/regularization_loss': 0.13482672,
#  'Loss/total_loss': 0.2335996,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.114s
# I0603 19:46:04.715268 140087170545472 model_lib_v2.py:705] Step 5200 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.07786262,
#  'Loss/localization_loss': 0.0192329,
#  'Loss/regularization_loss': 0.13431628,
#  'Loss/total_loss': 0.2314118,
#  'learning_rate': 0.07855851}
# I0603 19:46:04.715471 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.07786262,
#  'Loss/localization_loss': 0.0192329,
#  'Loss/regularization_loss': 0.13431628,
#  'Loss/total_loss': 0.2314118,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.113s
# I0603 19:46:16.032398 140087170545472 model_lib_v2.py:705] Step 5300 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.079641454,
#  'Loss/localization_loss': 0.013069516,
#  'Loss/regularization_loss': 0.13376556,
# ...
#  'learning_rate': 0.0005978322}
# INFO:tensorflow:Step 47400 per-step time 0.113s
# I0603 21:20:41.136970 140087170545472 model_lib_v2.py:705] Step 47400 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.031733636,
#  'Loss/localization_loss': 0.0027033866,
#  'Loss/regularization_loss': 0.058233395,
#  'Loss/total_loss': 0.09267042,
#  'learning_rate': 0.000554471}
# I0603 21:20:41.137173 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.031733636,
#  'Loss/localization_loss': 0.0027033866,
#  'Loss/regularization_loss': 0.058233395,
#  'Loss/total_loss': 0.09267042,
#  'learning_rate': 0.000554471}
# INFO:tensorflow:Step 47500 per-step time 0.113s
# I0603 21:20:52.447638 140087170545472 model_lib_v2.py:705] Step 47500 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.021298347,
#  'Loss/localization_loss': 0.002159271,
#  'Loss/regularization_loss': 0.058230896,
#  'Loss/total_loss': 0.081688516,
#  'learning_rate': 0.0005127263}
# I0603 21:20:52.447837 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.021298347,
#  'Loss/localization_loss': 0.002159271,
#  'Loss/regularization_loss': 0.058230896,
#  'Loss/total_loss': 0.081688516,
#  'learning_rate': 0.0005127263}
# INFO:tensorflow:Step 47600 per-step time 0.132s
# I0603 21:21:05.670175 140087170545472 model_lib_v2.py:705] Step 47600 per-step time 0.132s
# INFO:tensorflow:{'Loss/classification_loss': 0.01623718,
#  'Loss/localization_loss': 0.002573398,
#  'Loss/regularization_loss': 0.058228586,
#  'Loss/total_loss': 0.07703917,
#  'learning_rate': 0.00047260997}
# I0603 21:21:05.670405 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.01623718,
#  'Loss/localization_loss': 0.002573398,
#  'Loss/regularization_loss': 0.058228586,
#  'Loss/total_loss': 0.07703917,
#  'learning_rate': 0.00047260997}
# INFO:tensorflow:Step 47700 per-step time 0.117s
# I0603 21:21:17.343726 140087170545472 model_lib_v2.py:705] Step 47700 per-step time 0.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.021157987,
#  'Loss/localization_loss': 0.0019706767,
#  'Loss/regularization_loss': 0.05822646,
#  'Loss/total_loss': 0.081355125,
#  'learning_rate': 0.0004341173}
# I0603 21:21:17.343930 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.021157987,
#  'Loss/localization_loss': 0.0019706767,
#  'Loss/regularization_loss': 0.05822646,
#  'Loss/total_loss': 0.081355125,
#  'learning_rate': 0.0004341173}
# INFO:tensorflow:Step 47800 per-step time 0.116s
# I0603 21:21:28.971498 140087170545472 model_lib_v2.py:705] Step 47800 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.018978976,
#  'Loss/localization_loss': 0.0028854471,
#  'Loss/regularization_loss': 0.058224518,
#  'Loss/total_loss': 0.08008894,
#  'learning_rate': 0.00039724825}
# I0603 21:21:28.971699 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.018978976,
#  'Loss/localization_loss': 0.0028854471,
#  'Loss/regularization_loss': 0.058224518,
#  'Loss/total_loss': 0.08008894,
#  'learning_rate': 0.00039724825}
# INFO:tensorflow:Step 47900 per-step time 0.129s
# I0603 21:21:41.921084 140087170545472 model_lib_v2.py:705] Step 47900 per-step time 0.129s
# INFO:tensorflow:{'Loss/classification_loss': 0.018955315,
#  'Loss/localization_loss': 0.0033646207,
#  'Loss/regularization_loss': 0.058222745,
#  'Loss/total_loss': 0.08054268,
#  'learning_rate': 0.00036200762}
# I0603 21:21:41.921293 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.018955315,
#  'Loss/localization_loss': 0.0033646207,
#  'Loss/regularization_loss': 0.058222745,
#  'Loss/total_loss': 0.08054268,
#  'learning_rate': 0.00036200762}
# INFO:tensorflow:Step 48000 per-step time 0.153s
# I0603 21:21:57.207827 140087170545472 model_lib_v2.py:705] Step 48000 per-step time 0.153s
# INFO:tensorflow:{'Loss/classification_loss': 0.023265122,
#  'Loss/localization_loss': 0.0036786392,
#  'Loss/regularization_loss': 0.058221124,
#  'Loss/total_loss': 0.08516488,
#  'learning_rate': 0.00032839776}
# I0603 21:21:57.208081 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.023265122,
#  'Loss/localization_loss': 0.0036786392,
#  'Loss/regularization_loss': 0.058221124,
#  'Loss/total_loss': 0.08516488,
#  'learning_rate': 0.00032839776}
# INFO:tensorflow:Step 48100 per-step time 0.131s
# I0603 21:22:10.287091 140087170545472 model_lib_v2.py:705] Step 48100 per-step time 0.131s
# INFO:tensorflow:{'Loss/classification_loss': 0.03576147,
#  'Loss/localization_loss': 0.0039139143,
#  'Loss/regularization_loss': 0.05821966,
#  'Loss/total_loss': 0.09789504,
#  'learning_rate': 0.00029641867}
# I0603 21:22:10.287298 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.03576147,
#  'Loss/localization_loss': 0.0039139143,
#  'Loss/regularization_loss': 0.05821966,
#  'Loss/total_loss': 0.09789504,
#  'learning_rate': 0.00029641867}
# INFO:tensorflow:Step 48200 per-step time 0.128s
# I0603 21:22:23.133108 140087170545472 model_lib_v2.py:705] Step 48200 per-step time 0.128s
# INFO:tensorflow:{'Loss/classification_loss': 0.041724853,
#  'Loss/localization_loss': 0.007325752,
#  'Loss/regularization_loss': 0.058218334,
#  'Loss/total_loss': 0.107268944,
#  'learning_rate': 0.00026607275}
# I0603 21:22:23.133316 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.041724853,
#  'Loss/localization_loss': 0.007325752,
#  'Loss/regularization_loss': 0.058218334,
#  'Loss/total_loss': 0.107268944,
#  'learning_rate': 0.00026607275}
# INFO:tensorflow:Step 48300 per-step time 0.143s
# I0603 21:22:37.458184 140087170545472 model_lib_v2.py:705] Step 48300 per-step time 0.143s
# INFO:tensorflow:{'Loss/classification_loss': 0.02542652,
#  'Loss/localization_loss': 0.0021333005,
#  'Loss/regularization_loss': 0.058217153,
#  'Loss/total_loss': 0.08577697,
#  'learning_rate': 0.00023735761}
# I0603 21:22:37.458398 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.02542652,
#  'Loss/localization_loss': 0.0021333005,
#  'Loss/regularization_loss': 0.058217153,
#  'Loss/total_loss': 0.08577697,
#  'learning_rate': 0.00023735761}
# INFO:tensorflow:Step 48400 per-step time 0.135s
# I0603 21:22:50.918872 140087170545472 model_lib_v2.py:705] Step 48400 per-step time 0.135s
# INFO:tensorflow:{'Loss/classification_loss': 0.021332717,
#  'Loss/localization_loss': 0.0024869412,
#  'Loss/regularization_loss': 0.058216095,
#  'Loss/total_loss': 0.08203575,
#  'learning_rate': 0.00021027803}
# I0603 21:22:50.919090 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.021332717,
#  'Loss/localization_loss': 0.0024869412,
#  'Loss/regularization_loss': 0.058216095,
#  'Loss/total_loss': 0.08203575,
#  'learning_rate': 0.00021027803}
# INFO:tensorflow:Step 48500 per-step time 0.127s
# I0603 21:23:03.645228 140087170545472 model_lib_v2.py:705] Step 48500 per-step time 0.127s
# INFO:tensorflow:{'Loss/classification_loss': 0.014016189,
#  'Loss/localization_loss': 0.004976754,
#  'Loss/regularization_loss': 0.058215167,
#  'Loss/total_loss': 0.07720811,
#  'learning_rate': 0.000184834}
# I0603 21:23:03.645441 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.014016189,
#  'Loss/localization_loss': 0.004976754,
#  'Loss/regularization_loss': 0.058215167,
#  'Loss/total_loss': 0.07720811,
#  'learning_rate': 0.000184834}
# INFO:tensorflow:Step 48600 per-step time 0.113s
# I0603 21:23:14.978036 140087170545472 model_lib_v2.py:705] Step 48600 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.02201542,
#  'Loss/localization_loss': 0.0030790032,
#  'Loss/regularization_loss': 0.05821435,
#  'Loss/total_loss': 0.08330877,
#  'learning_rate': 0.0001610279}
# I0603 21:23:14.978255 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.02201542,
#  'Loss/localization_loss': 0.0030790032,
#  'Loss/regularization_loss': 0.05821435,
#  'Loss/total_loss': 0.08330877,
#  'learning_rate': 0.0001610279}
# INFO:tensorflow:Step 48700 per-step time 0.113s
# I0603 21:23:26.310418 140087170545472 model_lib_v2.py:705] Step 48700 per-step time 0.113s
# INFO:tensorflow:{'Loss/classification_loss': 0.02366259,
#  'Loss/localization_loss': 0.0030714646,
#  'Loss/regularization_loss': 0.058213647,
#  'Loss/total_loss': 0.084947705,
#  'learning_rate': 0.00013885974}
# I0603 21:23:26.310612 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.02366259,
#  'Loss/localization_loss': 0.0030714646,
#  'Loss/regularization_loss': 0.058213647,
#  'Loss/total_loss': 0.084947705,
#  'learning_rate': 0.00013885974}
# INFO:tensorflow:Step 48800 per-step time 0.114s
# I0603 21:23:37.710676 140087170545472 model_lib_v2.py:705] Step 48800 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.018580943,
#  'Loss/localization_loss': 0.002752853,
#  'Loss/regularization_loss': 0.058213037,
#  'Loss/total_loss': 0.07954683,
#  'learning_rate': 0.00011832714}
# I0603 21:23:37.710878 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.018580943,
#  'Loss/localization_loss': 0.002752853,
#  'Loss/regularization_loss': 0.058213037,
#  'Loss/total_loss': 0.07954683,
#  'learning_rate': 0.00011832714}
# INFO:tensorflow:Step 48900 per-step time 0.114s
# I0603 21:23:49.120923 140087170545472 model_lib_v2.py:705] Step 48900 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.018875936,
#  'Loss/localization_loss': 0.002333855,
#  'Loss/regularization_loss': 0.058212526,
#  'Loss/total_loss': 0.07942232,
#  'learning_rate': 9.943485e-05}
# I0603 21:23:49.121125 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.018875936,
#  'Loss/localization_loss': 0.002333855,
#  'Loss/regularization_loss': 0.058212526,
#  'Loss/total_loss': 0.07942232,
#  'learning_rate': 9.943485e-05}
# INFO:tensorflow:Step 49000 per-step time 0.115s
# I0603 21:24:00.601973 140087170545472 model_lib_v2.py:705] Step 49000 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.016696207,
#  'Loss/localization_loss': 0.0039051904,
#  'Loss/regularization_loss': 0.058212094,
#  'Loss/total_loss': 0.07881349,
#  'learning_rate': 8.218288e-05}
# I0603 21:24:00.602185 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.016696207,
#  'Loss/localization_loss': 0.0039051904,
#  'Loss/regularization_loss': 0.058212094,
#  'Loss/total_loss': 0.07881349,
#  'learning_rate': 8.218288e-05}
# INFO:tensorflow:Step 49100 per-step time 0.117s
# I0603 21:24:12.305372 140087170545472 model_lib_v2.py:705] Step 49100 per-step time 0.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.025931811,
#  'Loss/localization_loss': 0.0025036077,
#  'Loss/regularization_loss': 0.058211744,
#  'Loss/total_loss': 0.08664716,
#  'learning_rate': 6.6573615e-05}
# I0603 21:24:12.305590 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.025931811,
#  'Loss/localization_loss': 0.0025036077,
#  'Loss/regularization_loss': 0.058211744,
#  'Loss/total_loss': 0.08664716,
#  'learning_rate': 6.6573615e-05}
# INFO:tensorflow:Step 49200 per-step time 0.114s
# I0603 21:24:23.753256 140087170545472 model_lib_v2.py:705] Step 49200 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.014881148,
#  'Loss/localization_loss': 0.0026743491,
#  'Loss/regularization_loss': 0.05821146,
#  'Loss/total_loss': 0.07576696,
#  'learning_rate': 5.2604675e-05}
# I0603 21:24:23.753728 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.014881148,
#  'Loss/localization_loss': 0.0026743491,
#  'Loss/regularization_loss': 0.05821146,
#  'Loss/total_loss': 0.07576696,
#  'learning_rate': 5.2604675e-05}
# INFO:tensorflow:Step 49300 per-step time 0.115s
# I0603 21:24:35.252826 140087170545472 model_lib_v2.py:705] Step 49300 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.034660544,
#  'Loss/localization_loss': 0.0049590804,
#  'Loss/regularization_loss': 0.058211245,
#  'Loss/total_loss': 0.09783087,
#  'learning_rate': 4.0278435e-05}
# I0603 21:24:35.253035 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.034660544,
#  'Loss/localization_loss': 0.0049590804,
#  'Loss/regularization_loss': 0.058211245,
#  'Loss/total_loss': 0.09783087,
#  'learning_rate': 4.0278435e-05}
# INFO:tensorflow:Step 49400 per-step time 0.127s
# I0603 21:24:47.921766 140087170545472 model_lib_v2.py:705] Step 49400 per-step time 0.127s
# INFO:tensorflow:{'Loss/classification_loss': 0.027454693,
#  'Loss/localization_loss': 0.0030300566,
#  'Loss/regularization_loss': 0.05821109,
#  'Loss/total_loss': 0.08869584,
#  'learning_rate': 2.9592513e-05}
# I0603 21:24:47.921997 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.027454693,
#  'Loss/localization_loss': 0.0030300566,
#  'Loss/regularization_loss': 0.05821109,
#  'Loss/total_loss': 0.08869584,
#  'learning_rate': 2.9592513e-05}
# INFO:tensorflow:Step 49500 per-step time 0.116s
# I0603 21:24:59.477490 140087170545472 model_lib_v2.py:705] Step 49500 per-step time 0.116s
# INFO:tensorflow:{'Loss/classification_loss': 0.016831089,
#  'Loss/localization_loss': 0.0033310123,
#  'Loss/regularization_loss': 0.058210973,
#  'Loss/total_loss': 0.078373075,
#  'learning_rate': 2.055168e-05}
# I0603 21:24:59.477680 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.016831089,
#  'Loss/localization_loss': 0.0033310123,
#  'Loss/regularization_loss': 0.058210973,
#  'Loss/total_loss': 0.078373075,
#  'learning_rate': 2.055168e-05}
# INFO:tensorflow:Step 49600 per-step time 0.129s
# I0603 21:25:12.348975 140087170545472 model_lib_v2.py:705] Step 49600 per-step time 0.129s
# INFO:tensorflow:{'Loss/classification_loss': 0.01687194,
#  'Loss/localization_loss': 0.003581472,
#  'Loss/regularization_loss': 0.0582109,
#  'Loss/total_loss': 0.07866431,
#  'learning_rate': 1.3153553e-05}
# I0603 21:25:12.349197 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.01687194,
#  'Loss/localization_loss': 0.003581472,
#  'Loss/regularization_loss': 0.0582109,
#  'Loss/total_loss': 0.07866431,
#  'learning_rate': 1.3153553e-05}
# INFO:tensorflow:Step 49700 per-step time 0.136s
# I0603 21:25:25.960937 140087170545472 model_lib_v2.py:705] Step 49700 per-step time 0.136s
# INFO:tensorflow:{'Loss/classification_loss': 0.010542057,
#  'Loss/localization_loss': 0.0041975346,
#  'Loss/regularization_loss': 0.058210865,
#  'Loss/total_loss': 0.07295045,
#  'learning_rate': 7.398128e-06}
# I0603 21:25:25.961152 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.010542057,
#  'Loss/localization_loss': 0.0041975346,
#  'Loss/regularization_loss': 0.058210865,
#  'Loss/total_loss': 0.07295045,
#  'learning_rate': 7.398128e-06}
# INFO:tensorflow:Step 49800 per-step time 0.114s
# I0603 21:25:37.405892 140087170545472 model_lib_v2.py:705] Step 49800 per-step time 0.114s
# INFO:tensorflow:{'Loss/classification_loss': 0.014136344,
#  'Loss/localization_loss': 0.0027568508,
#  'Loss/regularization_loss': 0.05821085,
#  'Loss/total_loss': 0.07510404,
#  'learning_rate': 3.2877922e-06}
# I0603 21:25:37.406095 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.014136344,
#  'Loss/localization_loss': 0.0027568508,
#  'Loss/regularization_loss': 0.05821085,
#  'Loss/total_loss': 0.07510404,
#  'learning_rate': 3.2877922e-06}
# INFO:tensorflow:Step 49900 per-step time 0.115s
# I0603 21:25:48.926173 140087170545472 model_lib_v2.py:705] Step 49900 per-step time 0.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.027674384,
#  'Loss/localization_loss': 0.0048170867,
#  'Loss/regularization_loss': 0.058210846,
#  'Loss/total_loss': 0.09070232,
#  'learning_rate': 8.2254405e-07}
# I0603 21:25:48.926386 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.027674384,
#  'Loss/localization_loss': 0.0048170867,
#  'Loss/regularization_loss': 0.058210846,
#  'Loss/total_loss': 0.09070232,
#  'learning_rate': 8.2254405e-07}
# INFO:tensorflow:Step 50000 per-step time 0.128s
# I0603 21:26:01.698407 140087170545472 model_lib_v2.py:705] Step 50000 per-step time 0.128s
# INFO:tensorflow:{'Loss/classification_loss': 0.017364984,
#  'Loss/localization_loss': 0.0029908763,
#  'Loss/regularization_loss': 0.058210846,
#  'Loss/total_loss': 0.07856671,
#  'learning_rate': 0.0}
# I0603 21:26:01.698617 140087170545472 model_lib_v2.py:708] {'Loss/classification_loss': 0.017364984,
#  'Loss/localization_loss': 0.0029908763,
#  'Loss/regularization_loss': 0.058210846,
#  'Loss/total_loss': 0.07856671,
#  'learning_rate': 0.0}

# %% [markdown]
# # 6.&nbsp;Convert Model to TensorFlow Lite

# %%
# Make a directory to store the trained TFLite model
# !mkdir custom_model_lite
output_directory = 'custom_model_lite/'

# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = 'training'

# !python3 models/research/object_detection/export_tflite_graph_tf2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-06-03 21:26:47.222929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:47.249514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:47.249937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:47.259335: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 21:26:47.260836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:47.261312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:47.261711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:48.222782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:48.223179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:48.223206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 21:26:48.223456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:48.223696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0603 21:26:51.486969 140327554156352 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-03 21:26:54.108083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:54.108423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:54.108599: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:54.109074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:54.109101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 21:26:54.109259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:54.109297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0603 21:26:54.620571 140327554156352 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-03 21:26:55.223489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:55.223784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:55.224022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:55.224393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:55.224414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 21:26:55.224604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:55.224646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-06-03 21:26:55.594071: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# I0603 21:26:55.977483 140327554156352 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-03 21:26:56.759246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:56.759545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:56.759846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:56.760298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:56.760337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 21:26:56.760536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:26:56.760590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f9fbc062a30>, because it is not built.
# W0603 21:26:56.938377 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f9fbc062a30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9fac1a8820>, because it is not built.
# W0603 21:26:57.133384 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9fac1a8820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f904733d0>, because it is not built.
# W0603 21:26:57.133561 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f904733d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90473520>, because it is not built.
# W0603 21:26:57.133635 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90473520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f90473790>, because it is not built.
# W0603 21:26:57.133696 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f90473790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903ee370>, because it is not built.
# W0603 21:26:57.133753 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903ee370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903ee580>, because it is not built.
# W0603 21:26:57.133810 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903ee580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f903ee730>, because it is not built.
# W0603 21:26:57.133867 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f903ee730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903eea30>, because it is not built.
# W0603 21:26:57.133924 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903eea30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903e12e0>, because it is not built.
# W0603 21:26:57.133981 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903e12e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f903e18e0>, because it is not built.
# W0603 21:26:57.134038 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f9f903e18e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903e1700>, because it is not built.
# W0603 21:26:57.134095 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903e1700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903e1100>, because it is not built.
# W0603 21:26:57.134151 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903e1100>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8dc0>, because it is not built.
# W0603 21:26:57.134219 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9830e070>, because it is not built.
# W0603 21:26:57.134277 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9830e070>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9045cbe0>, because it is not built.
# W0603 21:26:57.134333 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9045cbe0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9045c2b0>, because it is not built.
# W0603 21:26:57.134389 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9045c2b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9045c5b0>, because it is not built.
# W0603 21:26:57.134444 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9045c5b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9045ca60>, because it is not built.
# W0603 21:26:57.134501 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9045ca60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9815b7f0>, because it is not built.
# W0603 21:26:57.134556 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9815b7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9815b4f0>, because it is not built.
# W0603 21:26:57.134611 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9815b4f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8df0>, because it is not built.
# W0603 21:26:57.134666 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8df0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903f57f0>, because it is not built.
# W0603 21:26:57.134722 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903f57f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f904114f0>, because it is not built.
# W0603 21:26:57.134778 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f904114f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90411460>, because it is not built.
# W0603 21:26:57.134833 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90411460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f90411670>, because it is not built.
# W0603 21:26:57.134888 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f90411670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f904116a0>, because it is not built.
# W0603 21:26:57.134943 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f904116a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f90411df0>, because it is not built.
# W0603 21:26:57.134999 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f90411df0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90411d60>, because it is not built.
# W0603 21:26:57.135054 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90411d60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8e20>, because it is not built.
# W0603 21:26:57.135109 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9fac1a8e20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90414a30>, because it is not built.
# W0603 21:26:57.135165 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f90414a30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f983bfbb0>, because it is not built.
# W0603 21:26:57.135230 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f983bfbb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f983bfee0>, because it is not built.
# W0603 21:26:57.135286 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f983bfee0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9046b8b0>, because it is not built.
# W0603 21:26:57.135342 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9046b8b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9046be50>, because it is not built.
# W0603 21:26:57.135397 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9046be50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9046b400>, because it is not built.
# W0603 21:26:57.135458 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9046b400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9046b790>, because it is not built.
# W0603 21:26:57.135519 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9046b790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903e71f0>, because it is not built.
# W0603 21:26:57.135575 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903e71f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903ba340>, because it is not built.
# W0603 21:26:57.135631 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903ba340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903bae50>, because it is not built.
# W0603 21:26:57.135686 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f903bae50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903baf40>, because it is not built.
# W0603 21:26:57.135741 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f903baf40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9043daf0>, because it is not built.
# W0603 21:26:57.135799 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9043daf0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9043db50>, because it is not built.
# W0603 21:26:57.135855 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9043db50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9043d4f0>, because it is not built.
# W0603 21:26:57.135914 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f9f9043d4f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9043d490>, because it is not built.
# W0603 21:26:57.135970 140327554156352 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f9f9043d490>, because it is not built.
# W0603 21:27:06.146898 140327554156352 save.py:260] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 104). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: custom_model_lite/saved_model/assets
# I0603 21:27:08.656144 140327554156352 builder_impl.py:779] Assets written to: custom_model_lite/saved_model/assets

# %%
# Convert exported graph file into TFLite model file
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('custom_model_lite/saved_model')
tflite_model = converter.convert()

with open('custom_model_lite/detect.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# 2023-06-03 21:29:29.775154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.775591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.775772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.776754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.776946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.777120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.784374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.784407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-03 21:29:29.784635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-03 21:29:29.784667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs
# 2023-06-03 21:29:36.297695: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-06-03 21:29:36.297748: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# 2023-06-03 21:29:36.299521: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: custom_model_lite/saved_model
# 2023-06-03 21:29:36.345751: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-06-03 21:29:36.345876: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: custom_model_lite/saved_model
# 2023-06-03 21:29:36.486355: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-06-03 21:29:37.050823: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: custom_model_lite/saved_model
# 2023-06-03 21:29:37.344790: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 1045290 microseconds.
# 2023-06-03 21:29:37.924501: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-03 21:29:38.784555: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1963] Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs

# %%
# !pip install tflite-support-nightly
# Out:
# Collecting tflite-support-nightly
#   Downloading tflite_support_nightly-0.4.4.dev20230522-cp38-cp38-manylinux2014_x86_64.whl (60.8 MB)
#      |████████████████████████████████| 60.8 MB 2.8 MB/s eta 0:00:01
# Collecting pybind11>=2.6.0
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      |████████████████████████████████| 222 kB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.0 in ./venv/lib/python3.8/site-packages (from tflite-support-nightly) (1.24.3)
# Requirement already satisfied: flatbuffers>=2.0 in ./venv/lib/python3.8/site-packages (from tflite-support-nightly) (23.5.26)
# Requirement already satisfied: protobuf<4,>=3.18.0 in ./venv/lib/python3.8/site-packages (from tflite-support-nightly) (3.20.3)
# Requirement already satisfied: absl-py>=0.7.0 in ./venv/lib/python3.8/site-packages (from tflite-support-nightly) (1.4.0)
# Collecting sounddevice>=0.4.4
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Collecting CFFI>=1.0
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      |████████████████████████████████| 442 kB 4.6 MB/s eta 0:00:01
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 5.3 MB/s eta 0:00:01
# Installing collected packages: pybind11, pycparser, CFFI, sounddevice, tflite-support-nightly
# Successfully installed CFFI-1.15.1 pybind11-2.10.4 pycparser-2.21 sounddevice-0.4.6 tflite-support-nightly-0.4.4.dev20230522

# %%
from tflite_support.metadata_writers import object_detector
from tflite_support.metadata_writers import metadata_info
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata_schema_py_generated as _metadata_fb

# %%
ObjectDetectorWriter = object_detector.MetadataWriter
_MODEL_PATH = "custom_model_lite/detect.tflite"
# Task Library expects label files that are in the same format as the one below.
_LABEL_FILE = "classes.txt"
_SAVE_TO_PATH = "model_metadata.tflite"
# Normalization parameters is required when reprocessing the image. It is
# optional if the image pixel values are in range of [0, 255] and the input
# tensor is quantized to uint8. See the introduction for normalization and
# quantization parameters below for more details.
# https://www.tensorflow.org/lite/models/convert/metadata#normalization_and_quantization_parameters)
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ObjectDetectorWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
from tflite_support import metadata

displayer = metadata.MetadataDisplayer.with_model_file("model_metadata.tflite")
print("Metadata populated:")
print(displayer.get_metadata_json())

print("Associated file(s) populated:")
for file_name in displayer.get_packed_associated_file_list():
  print("file name: ", file_name)
  print("file content:")
  print(displayer.get_associated_file_buffer(file_name))
# Out:
# Metadata populated:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ],
#   "min_parser_version": "1.2.0"
# }
#
# Associated file(s) populated:
# file name:  classes.txt
# file content:
# b'Nol\nSatu\nDua\nTiga\nEmpat\nLima\nEnam\nTujuh\nDelapan\nSembilan\nSepuluh'

# %% [markdown]
# # 7.&nbsp;Testing the Model

# %% [markdown]
# ## 7.1&nbsp;Inference Test Images

# %%
# Script to run custom TFLite model on test images to detect objects
# Source: https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/TFLite_detection_image.py

# Import packages
import os
import cv2
import numpy as np
import sys
import glob
import random
import importlib.util
from tensorflow.lite.python.interpreter import Interpreter

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

### Define function for inferencing with TFLite model and displaying results

def tflite_detect_images(modelpath, imgpath, lblpath, min_conf=0.5, num_test_images=10, savepath='results', txt_only=False):

  # Grab filenames of all images in test folder
  images = glob.glob(imgpath + '/*.jpg') + glob.glob(imgpath + '/*.JPG') + glob.glob(imgpath + '/*.png') + glob.glob(imgpath + '/*.bmp')

  # Load the label map into memory
  with open(lblpath, 'r') as f:
      labels = [line.strip() for line in f.readlines()]

  # Load the Tensorflow Lite model into memory
  interpreter = Interpreter(model_path=modelpath)
  interpreter.allocate_tensors()

  # Get model details
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  height = input_details[0]['shape'][1]
  width = input_details[0]['shape'][2]

  float_input = (input_details[0]['dtype'] == np.float32)

  input_mean = 127.5
  input_std = 127.5

  # Randomly select test images
  images_to_test = random.sample(images, num_test_images)

  # Loop over every image and perform detection
  for image_path in images_to_test:

      # Load image and resize to expected shape [1xHxWx3]
      image = cv2.imread(image_path)
      image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      imH, imW, _ = image.shape 
      image_resized = cv2.resize(image_rgb, (width, height))
      input_data = np.expand_dims(image_resized, axis=0)

      # Normalize pixel values if using a floating model (i.e. if model is non-quantized)
      if float_input:
          input_data = (np.float32(input_data) - input_mean) / input_std

      # Perform the actual detection by running the model with the image as input
      interpreter.set_tensor(input_details[0]['index'],input_data)
      interpreter.invoke()

      # Retrieve detection results
      boxes = interpreter.get_tensor(output_details[1]['index'])[0] # Bounding box coordinates of detected objects
      classes = interpreter.get_tensor(output_details[3]['index'])[0] # Class index of detected objects
      scores = interpreter.get_tensor(output_details[0]['index'])[0] # Confidence of detected objects

      detections = []

      # Loop over all detections and draw detection box if confidence is above minimum threshold
      for i in range(len(scores)):
          if ((scores[i] > min_conf) and (scores[i] <= 1.0)):

              # Get bounding box coordinates and draw box
              # Interpreter can return coordinates that are outside of image dimensions, need to force them to be within image using max() and min()
              ymin = int(max(1,(boxes[i][0] * imH)))
              xmin = int(max(1,(boxes[i][1] * imW)))
              ymax = int(min(imH,(boxes[i][2] * imH)))
              xmax = int(min(imW,(boxes[i][3] * imW)))
              
              cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (10, 255, 0), 2)

              # Draw label
              object_name = labels[int(classes[i])] # Look up object name from "labels" array using class index
              label = '%s: %d%%' % (object_name, int(scores[i]*100)) # Example: 'person: 72%'
              labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2) # Get font size
              label_ymin = max(ymin, labelSize[1] + 10) # Make sure not to draw label too close to top of window
              cv2.rectangle(image, (xmin, label_ymin-labelSize[1]-10), (xmin+labelSize[0], label_ymin+baseLine-10), (255, 255, 255), cv2.FILLED) # Draw white box to put label text in
              cv2.putText(image, label, (xmin, label_ymin-7), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2) # Draw label text

              detections.append([object_name, scores[i], xmin, ymin, xmax, ymax])

      
      # All the results have been drawn on the image, now display the image
      if txt_only == False: # "text_only" controls whether we want to display the image results or just save them in .txt files
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12,16))
        plt.imshow(image)
        plt.show()
      
      # Save detection results in .txt files (for calculating mAP)
      elif txt_only == True:

        # Get filenames and paths
        image_fn = os.path.basename(image_path)      
        base_fn, ext = os.path.splitext(image_fn)
        txt_result_fn = base_fn +'.txt'
        txt_savepath = os.path.join(savepath, txt_result_fn)

        # Write results to text file
        # (Using format defined by https://github.com/Cartucho/mAP, which will make it easy to calculate mAP)
        with open(txt_savepath,'w') as f:
            for detection in detections:
                f.write('%s %.4f %d %d %d %d\n' % (detection[0], detection[1], detection[2], detection[3], detection[4], detection[5]))

  return

# %%
# Set up variables for running user's model
PATH_TO_IMAGES='images/test'   # Path to test images folder
PATH_TO_MODEL='custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='labelmap.txt'   # Path to labelmap.txt file
min_conf_threshold=0.5   # Confidence threshold (try changing this to 0.01 if you don't see any detection results)
images_to_test=10   # Number of images to run detection on

# Run inferencing function!
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test)

# %% [markdown]
# ## 7.2.&nbsp;Calculate mAP

# %%
# %%bash
# git clone https://github.com/Cartucho/mAP /content/mAP
# cd /content/mAP
# rm input/detection-results/*
# rm input/ground-truth/*
# rm input/images-optional/*
# wget https://raw.githubusercontent.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/master/util_scripts/calculate_map_cartucho.py

# %%
# !cp images/test/* mAP/input/images-optional # Copy images and xml files
# !mv mAP/input/images-optional/*.xml mAP/input/ground-truth/  # Move xml files to the appropriate folder

# %%
# !python /content/mAP/scripts/extra/convert_gt_xml.py

# %%
# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='images/test'   # Path to test images folder
PATH_TO_MODEL='custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='labelmap.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.1 # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')

# %%
# %cd /content/mAP
# !python calculate_map_cartucho.py --labels=/content/labelmap.txt

# %% [markdown]
# # 8.&nbsp;(Optional) Post-Training Quantization

# %%
# Get list of all images in train directory
image_path = 'images/train'

jpg_file_list = glob.glob(image_path + '/*.jpg')
JPG_file_list = glob.glob(image_path + '/*.JPG')
png_file_list = glob.glob(image_path + '/*.png')
bmp_file_list = glob.glob(image_path + '/*.bmp')

quant_image_list = jpg_file_list + JPG_file_list + png_file_list + bmp_file_list

# %%
# A generator that provides a representative dataset
# Code modified from https://colab.research.google.com/github/google-coral/tutorials/blob/master/retrain_classification_ptq_tf2.ipynb

# First, get input details for model so we know how to preprocess images
interpreter = Interpreter(model_path=PATH_TO_MODEL)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
height = input_details[0]['shape'][1]
width = input_details[0]['shape'][2]

import random

def representative_data_gen():
  dataset_list = quant_image_list
  quant_num = 300
  for i in range(quant_num):
    pick_me = random.choice(dataset_list)
    image = tf.io.read_file(pick_me)

    if pick_me.endswith('.jpg') or pick_me.endswith('.JPG'):
      image = tf.io.decode_jpeg(image, channels=3)
    elif pick_me.endswith('.png'):
      image = tf.io.decode_png(image, channels=3)
    elif pick_me.endswith('.bmp'):
      image = tf.io.decode_bmp(image, channels=3)

    image = tf.image.resize(image, [width, height])
    image = tf.cast(image / 255., tf.float32)
    image = tf.expand_dims(image, 0)
    yield [image]

# %%
# Initialize converter module
converter = tf.lite.TFLiteConverter.from_saved_model('custom_model_lite/saved_model')

# This enables quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# This sets the representative dataset for quantization
converter.representative_dataset = representative_data_gen
# This ensures that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# For full integer quantization, though supported types defaults to int8 only, we explicitly declare it for clarity.
converter.target_spec.supported_types = [tf.int8]
# These set the input tensors to uint8 and output tensors to float32
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.float32
tflite_model = converter.convert()

with open('/content/custom_model_lite/detect_quant.tflite', 'wb') as f:
  f.write(tflite_model)
