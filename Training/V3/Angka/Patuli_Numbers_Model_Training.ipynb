# %% [markdown]
# ---
#
# # Patuli (C23-PS037) - Bangkit 2023 Capstone Project
#
# ---
#
# ## [**Numbers**] Model Training
#
# ---
#
# **Author:** Ammar Sufyan, Fauzan Farhan Antoro, Belvin Shandy Aurora
#
# **Github:** https://github.com/Patuli-Pahlawan-Tuli/Patuli-ML

# %% [markdown]
# # 1.&nbsp;Gather and Label Training Images

# %% [markdown]
# We first collected the Bisindo sign language dataset.
# *   For the alphabetical (A-Z) dataset we took from [here](https://www.kaggle.com/datasets/nando645/bisindo2).
# *   For the number and word datasets, we created our own by taking a photo of ourselves.

# %% [markdown]
# Next, after we finished collecting the dataset, we performed labeling using [label-studio](https://github.com/heartexlabs/label-studio).
#
# ![Screenshot 2023-06-03 105414.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2.&nbsp;Install TensorFlow Object Detection Dependencies

# %%
# !pip install tensorflow==2.8.0
# !pip install protobuf==3.20.*
# Out:
# Requirement already satisfied: tensorflow==2.8.0 in ./.venv/lib/python3.8/site-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (44.0.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (4.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.15.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.8/site-packages (from tensorflow==2.8.0) (1.54.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in ./.venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)
# Requirement already satisfied: protobuf==3.20.* in ./.venv/lib/python3.8/site-packages (3.20.3)

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0
# 2023-06-08 00:19:56.838297: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 00:19:57.035146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:57.082334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:57.082528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.081832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.082224: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.082234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-08 00:19:58.082624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.083067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-06-08 00:19:58.086176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.086805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.087178: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.087662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.087672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-08 00:19:58.088028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:19:58.088063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Clone the tensorflow models repository from GitHub
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3886, done.
# remote: Counting objects: 100% (3886/3886), done.
# remote: Compressing objects: 100% (2987/2987), done.
# remote: Total 3886 (delta 1123), reused 1997 (delta 849), pack-reused 0
# Receiving objects: 100% (3886/3886), 49.63 MiB | 1.64 MiB/s, done.
# Resolving deltas: 100% (1123/1123), done.

# %%
# Copy setup files into models/research folder 
# %cd models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# %cd ../..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/models/research
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka

# %%
# Modify setup.py file to install the tf-models-official repository targeted at TF v2.8.0
import re
with open('models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# Install the Object Detection API
# !pip install models/research/
# Out:
# Processing ./models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (0.29.35)
# Requirement already satisfied: apache-beam in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.48.0)
# Requirement already satisfied: avro-python3 in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: contextlib2 in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: keras in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: lvis in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: lxml in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.0.2)
# Requirement already satisfied: pillow in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (9.5.0)
# Requirement already satisfied: pycocotools in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: pyparsing==2.4.7 in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: six in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: tensorflow_io in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (0.32.0)
# Requirement already satisfied: tf-models-official==2.8.0 in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: tf-slim in ./.venv/lib/python3.8/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: gin-config in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.88.0)
# Requirement already satisfied: kaggle>=1.3.9 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.5.13)
# Requirement already satisfied: numpy>=1.15.4 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.24.3)
# Requirement already satisfied: oauth2client in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: psutil>=5.4.3 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.4.1)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.1.99)
# Requirement already satisfied: seqeval in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.20.0)
# Requirement already satisfied: tensorflow-datasets in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.13.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.7.5)
# Requirement already satisfied: tensorflow-text~=2.8.0 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: tensorflow~=2.8.0 in ./.venv/lib/python3.8/site-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.8/site-packages (from pandas->object-detection==0.1) (2023.3)
# Requirement already satisfied: portalocker in ./.venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: regex in ./.venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in ./.venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: colorama in ./.venv/lib/python3.8/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: absl-py>=0.2.2 in ./.venv/lib/python3.8/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.9.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.7.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.54.2)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (4.3.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (4.6.3)
# Requirement already satisfied: zstandard<1,>=0.18.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in ./.venv/lib/python3.8/site-packages (from apache-beam->object-detection==0.1) (11.0.0)
# Requirement already satisfied: cycler>=0.10.0 in ./.venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in ./.venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in ./.venv/lib/python3.8/site-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in ./.venv/lib/python3.8/site-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in ./.venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.19.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in ./.venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in ./.venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./.venv/lib/python3.8/site-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in ./.venv/lib/python3.8/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (8.0.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (4.65.0)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.8/site-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.26.16)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./.venv/lib/python3.8/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (44.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.15.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in ./.venv/lib/python3.8/site-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0.dev2021122109)
# Requirement already satisfied: dm-tree~=0.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in ./.venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in ./.venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in ./.venv/lib/python3.8/site-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in ./.venv/lib/python3.8/site-packages (from seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in ./.venv/lib/python3.8/site-packages (from tensorflow-addons->tf-models-official==2.8.0->object-detection==0.1) (2.13.3)
# Requirement already satisfied: array-record in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: click in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.3.0)
# Requirement already satisfied: promise in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.13.1)
# Requirement already satisfied: toml in ./.venv/lib/python3.8/site-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.40.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in ./.venv/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.8/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (5.3.1)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.8/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (3.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.3.4)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.8/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (6.6.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697016 sha256=b4ad469d99e7ab694cfe92d4025a5ce71129b3820494534eb32468457de3f8d7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-94egdzoi/wheels/4d/c6/ae/3fae6974602026bb46fae31320d70440674d3ac2beafab4f4d
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1

# %%
# Run Model Builder Test file, just to verify everything's working properly
# !python3 models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-06-08 00:44:18.358593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.364526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.364769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# Running tests under Python 3.8.10: /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-06-08 00:44:18.372856: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 00:44:18.374541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.375059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.375407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.816264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.816555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.816580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-08 00:44:18.816764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-08 00:44:18.816845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/builders/model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0608 00:44:19.205624 139837260814144 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.97s
# I0608 00:44:19.334235 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.97s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.28s
# I0608 00:44:19.617202 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.28s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.13s
# I0608 00:44:19.747645 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.18s
# I0608 00:44:19.929403 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.18s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.07s
# I0608 00:44:20.994836 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.07s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0608 00:44:20.995798 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0608 00:44:21.015557 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0608 00:44:21.025530 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0608 00:44:21.036363 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.07s
# I0608 00:44:21.111527 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# I0608 00:44:21.173019 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# I0608 00:44:21.235949 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# I0608 00:44:21.303191 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# I0608 00:44:21.354173 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0608 00:44:21.370799 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0608 00:44:21.554681 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0608 00:44:21.554820 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0608 00:44:21.554880 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0608 00:44:21.556375 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:21.568145 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:21.568276 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:21.606898 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:21.607041 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:21.704356 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:21.704469 139837260814144 efficientnet_model.py:144] round_filter input=40 output=40
# I0608 00:44:21.807389 139837260814144 efficientnet_model.py:144] round_filter input=40 output=40
# I0608 00:44:21.807730 139837260814144 efficientnet_model.py:144] round_filter input=80 output=80
# I0608 00:44:21.958749 139837260814144 efficientnet_model.py:144] round_filter input=80 output=80
# I0608 00:44:21.958881 139837260814144 efficientnet_model.py:144] round_filter input=112 output=112
# I0608 00:44:22.111340 139837260814144 efficientnet_model.py:144] round_filter input=112 output=112
# I0608 00:44:22.111473 139837260814144 efficientnet_model.py:144] round_filter input=192 output=192
# I0608 00:44:22.310671 139837260814144 efficientnet_model.py:144] round_filter input=192 output=192
# I0608 00:44:22.310795 139837260814144 efficientnet_model.py:144] round_filter input=320 output=320
# I0608 00:44:22.356619 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0608 00:44:22.378120 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:22.408343 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0608 00:44:22.408560 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I0608 00:44:22.408634 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I0608 00:44:22.409570 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:22.419550 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:22.419701 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:22.493483 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:22.493615 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:22.653635 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:22.653762 139837260814144 efficientnet_model.py:144] round_filter input=40 output=40
# I0608 00:44:22.811630 139837260814144 efficientnet_model.py:144] round_filter input=40 output=40
# I0608 00:44:22.811810 139837260814144 efficientnet_model.py:144] round_filter input=80 output=80
# I0608 00:44:23.006100 139837260814144 efficientnet_model.py:144] round_filter input=80 output=80
# I0608 00:44:23.006264 139837260814144 efficientnet_model.py:144] round_filter input=112 output=112
# I0608 00:44:23.213507 139837260814144 efficientnet_model.py:144] round_filter input=112 output=112
# I0608 00:44:23.213707 139837260814144 efficientnet_model.py:144] round_filter input=192 output=192
# I0608 00:44:23.466791 139837260814144 efficientnet_model.py:144] round_filter input=192 output=192
# I0608 00:44:23.466923 139837260814144 efficientnet_model.py:144] round_filter input=320 output=320
# I0608 00:44:23.563893 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0608 00:44:23.583404 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:23.616591 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0608 00:44:23.616735 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I0608 00:44:23.616842 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I0608 00:44:23.617761 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:23.628136 139837260814144 efficientnet_model.py:144] round_filter input=32 output=32
# I0608 00:44:23.628267 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:23.702664 139837260814144 efficientnet_model.py:144] round_filter input=16 output=16
# I0608 00:44:23.702793 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:23.853252 139837260814144 efficientnet_model.py:144] round_filter input=24 output=24
# I0608 00:44:23.853386 139837260814144 efficientnet_model.py:144] round_filter input=40 output=48
# I0608 00:44:24.110903 139837260814144 efficientnet_model.py:144] round_filter input=40 output=48
# I0608 00:44:24.111040 139837260814144 efficientnet_model.py:144] round_filter input=80 output=88
# I0608 00:44:24.317807 139837260814144 efficientnet_model.py:144] round_filter input=80 output=88
# I0608 00:44:24.317949 139837260814144 efficientnet_model.py:144] round_filter input=112 output=120
# I0608 00:44:24.551827 139837260814144 efficientnet_model.py:144] round_filter input=112 output=120
# I0608 00:44:24.551980 139837260814144 efficientnet_model.py:144] round_filter input=192 output=208
# I0608 00:44:24.820180 139837260814144 efficientnet_model.py:144] round_filter input=192 output=208
# I0608 00:44:24.820312 139837260814144 efficientnet_model.py:144] round_filter input=320 output=352
# I0608 00:44:24.928551 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=1408
# I0608 00:44:24.948505 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:24.982009 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0608 00:44:24.982140 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0608 00:44:24.982194 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0608 00:44:24.983134 139837260814144 efficientnet_model.py:144] round_filter input=32 output=40
# I0608 00:44:24.994333 139837260814144 efficientnet_model.py:144] round_filter input=32 output=40
# I0608 00:44:24.994460 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:25.076676 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:25.076821 139837260814144 efficientnet_model.py:144] round_filter input=24 output=32
# I0608 00:44:25.238335 139837260814144 efficientnet_model.py:144] round_filter input=24 output=32
# I0608 00:44:25.238472 139837260814144 efficientnet_model.py:144] round_filter input=40 output=48
# I0608 00:44:25.402795 139837260814144 efficientnet_model.py:144] round_filter input=40 output=48
# I0608 00:44:25.402915 139837260814144 efficientnet_model.py:144] round_filter input=80 output=96
# I0608 00:44:25.666692 139837260814144 efficientnet_model.py:144] round_filter input=80 output=96
# I0608 00:44:25.666830 139837260814144 efficientnet_model.py:144] round_filter input=112 output=136
# I0608 00:44:25.932944 139837260814144 efficientnet_model.py:144] round_filter input=112 output=136
# I0608 00:44:25.933096 139837260814144 efficientnet_model.py:144] round_filter input=192 output=232
# I0608 00:44:26.264723 139837260814144 efficientnet_model.py:144] round_filter input=192 output=232
# I0608 00:44:26.264934 139837260814144 efficientnet_model.py:144] round_filter input=320 output=384
# I0608 00:44:26.390826 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=1536
# I0608 00:44:26.413289 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:26.460497 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0608 00:44:26.460670 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I0608 00:44:26.460716 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0608 00:44:26.461832 139837260814144 efficientnet_model.py:144] round_filter input=32 output=48
# I0608 00:44:26.477258 139837260814144 efficientnet_model.py:144] round_filter input=32 output=48
# I0608 00:44:26.477426 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:26.569999 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:26.570184 139837260814144 efficientnet_model.py:144] round_filter input=24 output=32
# I0608 00:44:26.786636 139837260814144 efficientnet_model.py:144] round_filter input=24 output=32
# I0608 00:44:26.786775 139837260814144 efficientnet_model.py:144] round_filter input=40 output=56
# I0608 00:44:26.990459 139837260814144 efficientnet_model.py:144] round_filter input=40 output=56
# I0608 00:44:26.990595 139837260814144 efficientnet_model.py:144] round_filter input=80 output=112
# I0608 00:44:27.449976 139837260814144 efficientnet_model.py:144] round_filter input=80 output=112
# I0608 00:44:27.450118 139837260814144 efficientnet_model.py:144] round_filter input=112 output=160
# I0608 00:44:27.759320 139837260814144 efficientnet_model.py:144] round_filter input=112 output=160
# I0608 00:44:27.759455 139837260814144 efficientnet_model.py:144] round_filter input=192 output=272
# I0608 00:44:28.143712 139837260814144 efficientnet_model.py:144] round_filter input=192 output=272
# I0608 00:44:28.143842 139837260814144 efficientnet_model.py:144] round_filter input=320 output=448
# I0608 00:44:28.244488 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=1792
# I0608 00:44:28.266695 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:28.305685 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0608 00:44:28.305827 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0608 00:44:28.305982 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0608 00:44:28.307112 139837260814144 efficientnet_model.py:144] round_filter input=32 output=48
# I0608 00:44:28.317008 139837260814144 efficientnet_model.py:144] round_filter input=32 output=48
# I0608 00:44:28.317132 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:28.434211 139837260814144 efficientnet_model.py:144] round_filter input=16 output=24
# I0608 00:44:28.434348 139837260814144 efficientnet_model.py:144] round_filter input=24 output=40
# I0608 00:44:28.683025 139837260814144 efficientnet_model.py:144] round_filter input=24 output=40
# I0608 00:44:28.683165 139837260814144 efficientnet_model.py:144] round_filter input=40 output=64
# I0608 00:44:28.961282 139837260814144 efficientnet_model.py:144] round_filter input=40 output=64
# I0608 00:44:28.961456 139837260814144 efficientnet_model.py:144] round_filter input=80 output=128
# I0608 00:44:29.321978 139837260814144 efficientnet_model.py:144] round_filter input=80 output=128
# I0608 00:44:29.322172 139837260814144 efficientnet_model.py:144] round_filter input=112 output=176
# I0608 00:44:29.652810 139837260814144 efficientnet_model.py:144] round_filter input=112 output=176
# I0608 00:44:29.652945 139837260814144 efficientnet_model.py:144] round_filter input=192 output=304
# I0608 00:44:30.090767 139837260814144 efficientnet_model.py:144] round_filter input=192 output=304
# I0608 00:44:30.090905 139837260814144 efficientnet_model.py:144] round_filter input=320 output=512
# I0608 00:44:30.367866 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=2048
# I0608 00:44:30.390179 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:30.436033 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0608 00:44:30.436179 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0608 00:44:30.436259 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0608 00:44:30.437323 139837260814144 efficientnet_model.py:144] round_filter input=32 output=56
# I0608 00:44:30.447438 139837260814144 efficientnet_model.py:144] round_filter input=32 output=56
# I0608 00:44:30.447586 139837260814144 efficientnet_model.py:144] round_filter input=16 output=32
# I0608 00:44:30.570590 139837260814144 efficientnet_model.py:144] round_filter input=16 output=32
# I0608 00:44:30.570741 139837260814144 efficientnet_model.py:144] round_filter input=24 output=40
# I0608 00:44:30.861798 139837260814144 efficientnet_model.py:144] round_filter input=24 output=40
# I0608 00:44:30.861939 139837260814144 efficientnet_model.py:144] round_filter input=40 output=72
# I0608 00:44:31.155154 139837260814144 efficientnet_model.py:144] round_filter input=40 output=72
# I0608 00:44:31.155262 139837260814144 efficientnet_model.py:144] round_filter input=80 output=144
# I0608 00:44:31.535794 139837260814144 efficientnet_model.py:144] round_filter input=80 output=144
# I0608 00:44:31.535932 139837260814144 efficientnet_model.py:144] round_filter input=112 output=200
# I0608 00:44:31.915681 139837260814144 efficientnet_model.py:144] round_filter input=112 output=200
# I0608 00:44:31.915819 139837260814144 efficientnet_model.py:144] round_filter input=192 output=344
# I0608 00:44:32.439596 139837260814144 efficientnet_model.py:144] round_filter input=192 output=344
# I0608 00:44:32.439730 139837260814144 efficientnet_model.py:144] round_filter input=320 output=576
# I0608 00:44:32.586005 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0608 00:44:32.603710 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0608 00:44:32.656211 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0608 00:44:32.656341 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0608 00:44:32.656393 139837260814144 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0608 00:44:32.657263 139837260814144 efficientnet_model.py:144] round_filter input=32 output=64
# I0608 00:44:32.668501 139837260814144 efficientnet_model.py:144] round_filter input=32 output=64
# I0608 00:44:32.668634 139837260814144 efficientnet_model.py:144] round_filter input=16 output=32
# I0608 00:44:32.819173 139837260814144 efficientnet_model.py:144] round_filter input=16 output=32
# I0608 00:44:32.819313 139837260814144 efficientnet_model.py:144] round_filter input=24 output=48
# I0608 00:44:33.139230 139837260814144 efficientnet_model.py:144] round_filter input=24 output=48
# I0608 00:44:33.139343 139837260814144 efficientnet_model.py:144] round_filter input=40 output=80
# I0608 00:44:33.664412 139837260814144 efficientnet_model.py:144] round_filter input=40 output=80
# I0608 00:44:33.664580 139837260814144 efficientnet_model.py:144] round_filter input=80 output=160
# I0608 00:44:34.157933 139837260814144 efficientnet_model.py:144] round_filter input=80 output=160
# I0608 00:44:34.158067 139837260814144 efficientnet_model.py:144] round_filter input=112 output=224
# I0608 00:44:34.642083 139837260814144 efficientnet_model.py:144] round_filter input=112 output=224
# I0608 00:44:34.642223 139837260814144 efficientnet_model.py:144] round_filter input=192 output=384
# I0608 00:44:35.262028 139837260814144 efficientnet_model.py:144] round_filter input=192 output=384
# I0608 00:44:35.262172 139837260814144 efficientnet_model.py:144] round_filter input=320 output=640
# I0608 00:44:35.452292 139837260814144 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0608 00:44:35.471394 139837260814144 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.16s
# I0608 00:44:35.532227 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.16s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0608 00:44:35.538617 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0608 00:44:35.539696 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0608 00:44:35.540019 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0608 00:44:35.540818 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0608 00:44:35.541529 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0608 00:44:35.541777 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0608 00:44:35.542307 139837260814144 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 17.176s
#
# OK (skipped=1)

# %% [markdown]
# # 3.&nbsp;Preprocessing Data

# %% [markdown]
# We performed data preprocessing using the [Roboflow](https://roboflow.com/) platform.

# %% [markdown]
# ## 3.1&nbsp;Uploading Data and Splitting Data

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3.2&nbsp;Resizing and Augmenting Data

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3.3&nbsp;Download the Data and Convert to TFRecord

# %%
# Install Roboflow library to download the dataset
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in ./.venv/lib/python3.8/site-packages (1.0.9)
# Requirement already satisfied: certifi==2022.12.7 in ./.venv/lib/python3.8/site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in ./.venv/lib/python3.8/site-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in ./.venv/lib/python3.8/site-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in ./.venv/lib/python3.8/site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.8/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.8/site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.8/site-packages (from roboflow) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.2 in ./.venv/lib/python3.8/site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in ./.venv/lib/python3.8/site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: pyparsing==2.4.7 in ./.venv/lib/python3.8/site-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.8/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.8/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.8/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in ./.venv/lib/python3.8/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./.venv/lib/python3.8/site-packages (from roboflow) (1.26.16)
# Requirement already satisfied: wget in ./.venv/lib/python3.8/site-packages (from roboflow) (3.2)
# Requirement already satisfied: tqdm>=4.41.0 in ./.venv/lib/python3.8/site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in ./.venv/lib/python3.8/site-packages (from roboflow) (5.4.1)
# Requirement already satisfied: requests-toolbelt in ./.venv/lib/python3.8/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.8/site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->roboflow) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.8/site-packages (from matplotlib->roboflow) (5.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests->roboflow) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.15.0)

# %%
# install the dotenv to get the key
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.8/site-packages (1.0.0)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key=os.getenv("api_key_patuli")

# %%
# Download the dataset
from roboflow import Roboflow
rf = Roboflow(api_key=api_key, model_format="voc")
dataset = rf.workspace().project("patuli-numbers-dataset").version(1).download(location="images")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in images to voc: 100% [52911881 / 52911881] bytes
# Extracting Dataset Version Zip to images in voc:: 100%|██████████| 8715/8715 [00:00<00:00, 23607.00it/s]

# %%
# Download data conversion scripts
# !wget https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/create_csv_modified.py
# !wget https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/create_tfrecord.py
# Out:
# --2023-06-08 00:45:08--  https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/create_csv_modified.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1416 (1.4K) [text/plain]
# Saving to: ‘create_csv_modified.py’
#
# create_csv_modified 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2023-06-08 00:45:09 (20.0 MB/s) - ‘create_csv_modified.py’ saved [1416/1416]
#
# --2023-06-08 00:45:09--  https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/create_tfrecord.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4414 (4.3K) [text/plain]
# Saving to: ‘create_tfrecord.py’
#
# create_tfrecord.py  100%[===================>]   4.31K  --.-KB/s    in 0.001s
#
# 2023-06-08 00:45:10 (6.02 MB/s) - ‘create_tfrecord.py’ saved [4414/4414]

# %%
# Create CSV data files and TFRecord files
# !python3 create_csv_modified.py
# !python3 create_tfrecord.py --csv_input=images/train_labels.csv --labelmap=classes.txt --image_dir=images/train --output_path=train.tfrecord
# !python3 create_tfrecord.py --csv_input=images/valid_labels.csv --labelmap=classes.txt --image_dir=images/valid --output_path=val.tfrecord
# Out:
# Successfully converted xml to csv.
# Successfully converted xml to csv.
# 2023-06-09 16:29:32.966600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:33.010404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:33.010609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# Successfully created the TFRecords: /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/train.tfrecord
# 2023-06-09 16:29:36.511267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:36.515932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:36.516130: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# Successfully created the TFRecords: /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/val.tfrecord

# %%
train_record_fname = 'train.tfrecord'
val_record_fname = 'val.tfrecord'
label_map_pbtxt_fname = 'labelmap.pbtxt'

# %% [markdown]
# # 4.&nbsp;Setup Training

# %%
#Models available in the TF2 object detection zoo
chosen_model = 'ssd-mobilenet-v2-fpnlite-320'

MODELS_CONFIG = {
      'ssd-mobilenet-v2-fpnlite-320': {
        'model_name': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8',
        'base_pipeline_file': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config',
        'pretrained_checkpoint': 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz',
    }
}

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']

# %%
# Create "mymodel" folder for holding pre-trained weights and configuration files
# %mkdir models/config/
# %cd models/config/

# Download pre-trained model weights
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

# Download training configuration file for model
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}

# %cd ../..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/models/config
# --2023-06-09 16:29:37--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.200.128, 2404:6800:4003:c04::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.200.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  6.00MB/s    in 3.3s
#
# 2023-06-09 16:29:41 (5.92 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# --2023-06-09 16:29:41--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4684 (4.6K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’
#
# ssd_mobilenet_v2_fp 100%[===================>]   4.57K  --.-KB/s    in 0.004s
#
# 2023-06-09 16:29:42 (1.03 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.config’ saved [4684/4684]
#
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka

# %%
# Set training parameters for the model
num_steps = 20000
batch_size = 16

# %%
# Set file locations and get number of classes for config file
pipeline_fname = 'models/config/' + base_pipeline_file
fine_tune_checkpoint = 'models/config/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)
print('Total classes:', num_classes)
# Out:
# Total classes: 11

# %%
# Create custom configuration file by writing the dataset, model checkpoint, and training parameters into the base pipeline file
import re

print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()

with open('models/config/pipeline_file.config', 'w') as f:
    
    # Set fine_tune_checkpoint path
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # Set tfrecord files for train and test datasets
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    # Set label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set batch_size
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    # Change fine-tune checkpoint type from "classification" to "detection"
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)
    
    # Reduce learning rate (because it's too high in the default config file)
    s = re.sub('learning_rate_base: .8',
               'learning_rate_base: .08', s)
      
    s = re.sub('warmup_learning_rate: 0.13333',
               'warmup_learning_rate: .026666', s)

    f.write(s)
# Out:
# writing custom configuration file

# %%
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = 'models/config/pipeline_file.config'
model_dir = 'training'

# %% [markdown]
# # 5.&nbsp;Start Training

# %%
# Run training!
# !python3 models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2023-06-09 16:29:46.110798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:46.117760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:46.118103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:46.120575: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-09 16:29:46.122890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:46.123302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:46.123705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:47.177148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:47.177801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:47.177912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 16:29:47.178439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 16:29:47.179016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0609 16:29:47.414349 140610980919104 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 20000
# I0609 16:29:47.416403 140610980919104 config_util.py:552] Maybe overwriting train_steps: 20000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0609 16:29:47.416511 140610980919104 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0609 16:29:47.496179 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['train.tfrecord']
# I0609 16:29:47.503083 140610980919104 dataset_builder.py:162] Reading unweighted datasets: ['train.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['train.tfrecord']
# I0609 16:29:47.503267 140610980919104 dataset_builder.py:79] Reading record datasets for input file: ['train.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0609 16:29:47.503334 140610980919104 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0609 16:29:47.503387 140610980919104 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0609 16:29:47.506057 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0609 16:29:47.524353 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0609 16:29:50.662153 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0609 16:29:52.080572 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0609 16:29:52.864731 140610980919104 deprecation.py:337] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0609 16:29:57.149228 140604965099264 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0609 16:30:03.918145 140604965099264 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-09 16:30:10.130423: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2023-06-09 16:30:11.625837: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-09 16:30:11.634338: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-06-09 16:30:11.634366: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at /usr/local/cuda-11.2/bin/ptxas
# 2023-06-09 16:30:11.634407: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: /usr/local/cuda-11.2/bin/ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-06-09 16:30:12.829286: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.879418 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.880218 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.881399 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.882146 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.883913 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.884511 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.885861 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.886406 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.887848 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0609 16:30:13.888433 140610980919104 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0609 16:30:14.255277 140605015455488 deprecation.py:541] From /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0609 16:30:14.812091 140605015455488 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0609 16:30:20.368826 140605015455488 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0609 16:30:26.096234 140605015455488 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0609 16:30:31.497173 140605015455488 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.480s
# I0609 16:31:02.060985 140610980919104 model_lib_v2.py:705] Step 100 per-step time 0.480s
# INFO:tensorflow:{'Loss/classification_loss': 0.48564112,
#  'Loss/localization_loss': 0.21527493,
#  'Loss/regularization_loss': 0.15347302,
#  'Loss/total_loss': 0.8543891,
#  'learning_rate': 0.0319994}
# I0609 16:31:02.061253 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.48564112,
#  'Loss/localization_loss': 0.21527493,
#  'Loss/regularization_loss': 0.15347302,
#  'Loss/total_loss': 0.8543891,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.202s
# I0609 16:31:22.261715 140610980919104 model_lib_v2.py:705] Step 200 per-step time 0.202s
# INFO:tensorflow:{'Loss/classification_loss': 0.33237237,
#  'Loss/localization_loss': 0.07848573,
#  'Loss/regularization_loss': 0.15331014,
#  'Loss/total_loss': 0.5641682,
#  'learning_rate': 0.0373328}
# I0609 16:31:22.261987 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.33237237,
#  'Loss/localization_loss': 0.07848573,
#  'Loss/regularization_loss': 0.15331014,
#  'Loss/total_loss': 0.5641682,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.203s
# I0609 16:31:42.522129 140610980919104 model_lib_v2.py:705] Step 300 per-step time 0.203s
# INFO:tensorflow:{'Loss/classification_loss': 0.22458303,
#  'Loss/localization_loss': 0.14050302,
#  'Loss/regularization_loss': 0.15301852,
#  'Loss/total_loss': 0.51810455,
#  'learning_rate': 0.0426662}
# I0609 16:31:42.522407 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.22458303,
#  'Loss/localization_loss': 0.14050302,
#  'Loss/regularization_loss': 0.15301852,
#  'Loss/total_loss': 0.51810455,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.199s
# I0609 16:32:02.451173 140610980919104 model_lib_v2.py:705] Step 400 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.2070818,
#  'Loss/localization_loss': 0.054469418,
#  'Loss/regularization_loss': 0.15270482,
#  'Loss/total_loss': 0.41425604,
#  'learning_rate': 0.047999598}
# I0609 16:32:02.451395 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.2070818,
#  'Loss/localization_loss': 0.054469418,
#  'Loss/regularization_loss': 0.15270482,
#  'Loss/total_loss': 0.41425604,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.199s
# I0609 16:32:22.366851 140610980919104 model_lib_v2.py:705] Step 500 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.2154795,
#  'Loss/localization_loss': 0.059151325,
#  'Loss/regularization_loss': 0.15235461,
#  'Loss/total_loss': 0.42698544,
#  'learning_rate': 0.053333}
# I0609 16:32:22.367114 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.2154795,
#  'Loss/localization_loss': 0.059151325,
#  'Loss/regularization_loss': 0.15235461,
#  'Loss/total_loss': 0.42698544,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.199s
# I0609 16:32:42.260252 140610980919104 model_lib_v2.py:705] Step 600 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.23512873,
#  'Loss/localization_loss': 0.05590009,
#  'Loss/regularization_loss': 0.15201409,
#  'Loss/total_loss': 0.44304293,
#  'learning_rate': 0.0586664}
# I0609 16:32:42.260450 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.23512873,
#  'Loss/localization_loss': 0.05590009,
#  'Loss/regularization_loss': 0.15201409,
#  'Loss/total_loss': 0.44304293,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.198s
# I0609 16:33:02.093340 140610980919104 model_lib_v2.py:705] Step 700 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.21127728,
#  'Loss/localization_loss': 0.042694613,
#  'Loss/regularization_loss': 0.15162566,
#  'Loss/total_loss': 0.40559754,
#  'learning_rate': 0.0639998}
# I0609 16:33:02.093566 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.21127728,
#  'Loss/localization_loss': 0.042694613,
#  'Loss/regularization_loss': 0.15162566,
#  'Loss/total_loss': 0.40559754,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.198s
# I0609 16:33:21.859372 140610980919104 model_lib_v2.py:705] Step 800 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.18687056,
#  'Loss/localization_loss': 0.043887362,
#  'Loss/regularization_loss': 0.1512432,
#  'Loss/total_loss': 0.3820011,
#  'learning_rate': 0.069333196}
# I0609 16:33:21.859572 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.18687056,
#  'Loss/localization_loss': 0.043887362,
#  'Loss/regularization_loss': 0.1512432,
#  'Loss/total_loss': 0.3820011,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.199s
# I0609 16:33:41.734783 140610980919104 model_lib_v2.py:705] Step 900 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.11415795,
#  'Loss/localization_loss': 0.042840254,
#  'Loss/regularization_loss': 0.15085909,
#  'Loss/total_loss': 0.30785728,
#  'learning_rate': 0.074666604}
# I0609 16:33:41.734967 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.11415795,
#  'Loss/localization_loss': 0.042840254,
#  'Loss/regularization_loss': 0.15085909,
#  'Loss/total_loss': 0.30785728,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.198s
# I0609 16:34:01.494965 140610980919104 model_lib_v2.py:705] Step 1000 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.14986409,
#  'Loss/localization_loss': 0.040209763,
#  'Loss/regularization_loss': 0.1504066,
#  'Loss/total_loss': 0.34048045,
#  'learning_rate': 0.08}
# I0609 16:34:01.495166 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.14986409,
#  'Loss/localization_loss': 0.040209763,
#  'Loss/regularization_loss': 0.1504066,
#  'Loss/total_loss': 0.34048045,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.202s
# I0609 16:34:21.661471 140610980919104 model_lib_v2.py:705] Step 1100 per-step time 0.202s
# INFO:tensorflow:{'Loss/classification_loss': 0.12321475,
#  'Loss/localization_loss': 0.049795322,
#  'Loss/regularization_loss': 0.150064,
#  'Loss/total_loss': 0.3230741,
#  'learning_rate': 0.07999918}
# I0609 16:34:21.661663 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.12321475,
#  'Loss/localization_loss': 0.049795322,
#  'Loss/regularization_loss': 0.150064,
#  'Loss/total_loss': 0.3230741,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.197s
# I0609 16:34:41.401183 140610980919104 model_lib_v2.py:705] Step 1200 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.1324591,
#  'Loss/localization_loss': 0.04021569,
#  'Loss/regularization_loss': 0.14960484,
#  'Loss/total_loss': 0.32227963,
#  'learning_rate': 0.079996705}
# I0609 16:34:41.401417 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.1324591,
#  'Loss/localization_loss': 0.04021569,
#  'Loss/regularization_loss': 0.14960484,
#  'Loss/total_loss': 0.32227963,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.199s
# I0609 16:35:01.266127 140610980919104 model_lib_v2.py:705] Step 1300 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.11042433,
#  'Loss/localization_loss': 0.034418043,
#  'Loss/regularization_loss': 0.14898929,
#  'Loss/total_loss': 0.29383165,
#  'learning_rate': 0.0799926}
# I0609 16:35:01.266333 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.11042433,
#  'Loss/localization_loss': 0.034418043,
#  'Loss/regularization_loss': 0.14898929,
#  'Loss/total_loss': 0.29383165,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.196s
# I0609 16:35:20.862508 140610980919104 model_lib_v2.py:705] Step 1400 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.097228654,
#  'Loss/localization_loss': 0.02556918,
#  'Loss/regularization_loss': 0.14844348,
#  'Loss/total_loss': 0.2712413,
#  'learning_rate': 0.07998685}
# I0609 16:35:20.862735 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.097228654,
#  'Loss/localization_loss': 0.02556918,
#  'Loss/regularization_loss': 0.14844348,
#  'Loss/total_loss': 0.2712413,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.197s
# I0609 16:35:40.522594 140610980919104 model_lib_v2.py:705] Step 1500 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.07976719,
#  'Loss/localization_loss': 0.023552164,
#  'Loss/regularization_loss': 0.1480399,
#  'Loss/total_loss': 0.25135925,
#  'learning_rate': 0.07997945}
# I0609 16:35:40.522769 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.07976719,
#  'Loss/localization_loss': 0.023552164,
#  'Loss/regularization_loss': 0.1480399,
#  'Loss/total_loss': 0.25135925,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.195s
# I0609 16:36:00.052123 140610980919104 model_lib_v2.py:705] Step 1600 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.09655965,
#  'Loss/localization_loss': 0.036667604,
#  'Loss/regularization_loss': 0.14763954,
#  'Loss/total_loss': 0.2808668,
#  'learning_rate': 0.079970405}
# I0609 16:36:00.052318 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.09655965,
#  'Loss/localization_loss': 0.036667604,
#  'Loss/regularization_loss': 0.14763954,
#  'Loss/total_loss': 0.2808668,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.197s
# I0609 16:36:19.786594 140610980919104 model_lib_v2.py:705] Step 1700 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.112742804,
#  'Loss/localization_loss': 0.029746497,
#  'Loss/regularization_loss': 0.14710681,
#  'Loss/total_loss': 0.2895961,
#  'learning_rate': 0.07995972}
# I0609 16:36:19.787116 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.112742804,
#  'Loss/localization_loss': 0.029746497,
#  'Loss/regularization_loss': 0.14710681,
#  'Loss/total_loss': 0.2895961,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.196s
# I0609 16:36:39.411051 140610980919104 model_lib_v2.py:705] Step 1800 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.058507867,
#  'Loss/localization_loss': 0.021685667,
#  'Loss/regularization_loss': 0.14639638,
#  'Loss/total_loss': 0.22658992,
#  'learning_rate': 0.0799474}
# I0609 16:36:39.411311 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.058507867,
#  'Loss/localization_loss': 0.021685667,
#  'Loss/regularization_loss': 0.14639638,
#  'Loss/total_loss': 0.22658992,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.197s
# I0609 16:36:59.072059 140610980919104 model_lib_v2.py:705] Step 1900 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.25735793,
#  'Loss/localization_loss': 0.023901409,
#  'Loss/regularization_loss': 0.14577748,
#  'Loss/total_loss': 0.42703682,
#  'learning_rate': 0.07993342}
# I0609 16:36:59.072250 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.25735793,
#  'Loss/localization_loss': 0.023901409,
#  'Loss/regularization_loss': 0.14577748,
#  'Loss/total_loss': 0.42703682,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.198s
# I0609 16:37:18.894134 140610980919104 model_lib_v2.py:705] Step 2000 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.082164295,
#  'Loss/localization_loss': 0.020243404,
#  'Loss/regularization_loss': 0.14528276,
#  'Loss/total_loss': 0.24769047,
#  'learning_rate': 0.07991781}
# I0609 16:37:18.894331 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.082164295,
#  'Loss/localization_loss': 0.020243404,
#  'Loss/regularization_loss': 0.14528276,
#  'Loss/total_loss': 0.24769047,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.197s
# I0609 16:37:38.616595 140610980919104 model_lib_v2.py:705] Step 2100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.057456773,
#  'Loss/localization_loss': 0.017186636,
#  'Loss/regularization_loss': 0.14454865,
#  'Loss/total_loss': 0.21919206,
#  'learning_rate': 0.07990056}
# I0609 16:37:38.616786 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.057456773,
#  'Loss/localization_loss': 0.017186636,
#  'Loss/regularization_loss': 0.14454865,
#  'Loss/total_loss': 0.21919206,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.198s
# I0609 16:37:58.431071 140610980919104 model_lib_v2.py:705] Step 2200 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.07160066,
#  'Loss/localization_loss': 0.019388977,
#  'Loss/regularization_loss': 0.14374664,
#  'Loss/total_loss': 0.23473628,
#  'learning_rate': 0.07988167}
# I0609 16:37:58.431392 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.07160066,
#  'Loss/localization_loss': 0.019388977,
#  'Loss/regularization_loss': 0.14374664,
#  'Loss/total_loss': 0.23473628,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.196s
# I0609 16:38:18.057043 140610980919104 model_lib_v2.py:705] Step 2300 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.06998568,
#  'Loss/localization_loss': 0.02282766,
#  'Loss/regularization_loss': 0.14322545,
#  'Loss/total_loss': 0.23603879,
#  'learning_rate': 0.07986114}
# I0609 16:38:18.057219 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.06998568,
#  'Loss/localization_loss': 0.02282766,
#  'Loss/regularization_loss': 0.14322545,
#  'Loss/total_loss': 0.23603879,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.196s
# I0609 16:38:37.616786 140610980919104 model_lib_v2.py:705] Step 2400 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.108594194,
#  'Loss/localization_loss': 0.031357117,
#  'Loss/regularization_loss': 0.14276555,
#  'Loss/total_loss': 0.28271687,
#  'learning_rate': 0.07983897}
# I0609 16:38:37.616971 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.108594194,
#  'Loss/localization_loss': 0.031357117,
#  'Loss/regularization_loss': 0.14276555,
#  'Loss/total_loss': 0.28271687,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.196s
# I0609 16:38:57.186517 140610980919104 model_lib_v2.py:705] Step 2500 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.07525609,
#  'Loss/localization_loss': 0.025924858,
#  'Loss/regularization_loss': 0.14234649,
#  'Loss/total_loss': 0.24352743,
#  'learning_rate': 0.079815164}
# I0609 16:38:57.186693 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.07525609,
#  'Loss/localization_loss': 0.025924858,
#  'Loss/regularization_loss': 0.14234649,
#  'Loss/total_loss': 0.24352743,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.195s
# I0609 16:39:16.660724 140610980919104 model_lib_v2.py:705] Step 2600 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.063231066,
#  'Loss/localization_loss': 0.019928122,
#  'Loss/regularization_loss': 0.1416374,
#  'Loss/total_loss': 0.2247966,
#  'learning_rate': 0.07978972}
# I0609 16:39:16.660902 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.063231066,
#  'Loss/localization_loss': 0.019928122,
#  'Loss/regularization_loss': 0.1416374,
#  'Loss/total_loss': 0.2247966,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.197s
# I0609 16:39:36.352149 140610980919104 model_lib_v2.py:705] Step 2700 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.061032716,
#  'Loss/localization_loss': 0.019503783,
#  'Loss/regularization_loss': 0.14097589,
#  'Loss/total_loss': 0.22151239,
#  'learning_rate': 0.07976264}
# I0609 16:39:36.352462 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.061032716,
#  'Loss/localization_loss': 0.019503783,
#  'Loss/regularization_loss': 0.14097589,
#  'Loss/total_loss': 0.22151239,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.195s
# I0609 16:39:55.885453 140610980919104 model_lib_v2.py:705] Step 2800 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.06430658,
#  'Loss/localization_loss': 0.017025096,
#  'Loss/regularization_loss': 0.14031304,
#  'Loss/total_loss': 0.22164473,
#  'learning_rate': 0.07973392}
# I0609 16:39:55.885879 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.06430658,
#  'Loss/localization_loss': 0.017025096,
#  'Loss/regularization_loss': 0.14031304,
#  'Loss/total_loss': 0.22164473,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.196s
# I0609 16:40:15.482066 140610980919104 model_lib_v2.py:705] Step 2900 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.07299368,
#  'Loss/localization_loss': 0.021936113,
#  'Loss/regularization_loss': 0.13960241,
#  'Loss/total_loss': 0.2345322,
#  'learning_rate': 0.07970358}
# I0609 16:40:15.482251 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.07299368,
#  'Loss/localization_loss': 0.021936113,
#  'Loss/regularization_loss': 0.13960241,
#  'Loss/total_loss': 0.2345322,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.194s
# I0609 16:40:34.912144 140610980919104 model_lib_v2.py:705] Step 3000 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.046668842,
#  'Loss/localization_loss': 0.017276382,
#  'Loss/regularization_loss': 0.13892491,
#  'Loss/total_loss': 0.20287013,
#  'learning_rate': 0.0796716}
# I0609 16:40:34.912332 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.046668842,
#  'Loss/localization_loss': 0.017276382,
#  'Loss/regularization_loss': 0.13892491,
#  'Loss/total_loss': 0.20287013,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.201s
# I0609 16:40:55.029016 140610980919104 model_lib_v2.py:705] Step 3100 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.085413866,
#  'Loss/localization_loss': 0.022044169,
#  'Loss/regularization_loss': 0.13841107,
#  'Loss/total_loss': 0.2458691,
#  'learning_rate': 0.07963799}
# I0609 16:40:55.029197 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.085413866,
#  'Loss/localization_loss': 0.022044169,
#  'Loss/regularization_loss': 0.13841107,
#  'Loss/total_loss': 0.2458691,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.196s
# I0609 16:41:14.580611 140610980919104 model_lib_v2.py:705] Step 3200 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.110486746,
#  'Loss/localization_loss': 0.026151592,
#  'Loss/regularization_loss': 0.13852099,
#  'Loss/total_loss': 0.27515933,
#  'learning_rate': 0.07960275}
# I0609 16:41:14.580801 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.110486746,
#  'Loss/localization_loss': 0.026151592,
#  'Loss/regularization_loss': 0.13852099,
#  'Loss/total_loss': 0.27515933,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.194s
# I0609 16:41:34.007200 140610980919104 model_lib_v2.py:705] Step 3300 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.056089863,
#  'Loss/localization_loss': 0.02334464,
#  'Loss/regularization_loss': 0.13906723,
#  'Loss/total_loss': 0.21850173,
#  'learning_rate': 0.07956588}
# I0609 16:41:34.007370 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.056089863,
#  'Loss/localization_loss': 0.02334464,
#  'Loss/regularization_loss': 0.13906723,
#  'Loss/total_loss': 0.21850173,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.195s
# I0609 16:41:53.503700 140610980919104 model_lib_v2.py:705] Step 3400 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.047351364,
#  'Loss/localization_loss': 0.017413158,
#  'Loss/regularization_loss': 0.13846229,
#  'Loss/total_loss': 0.2032268,
#  'learning_rate': 0.079527386}
# I0609 16:41:53.503875 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.047351364,
#  'Loss/localization_loss': 0.017413158,
#  'Loss/regularization_loss': 0.13846229,
#  'Loss/total_loss': 0.2032268,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.195s
# I0609 16:42:12.993751 140610980919104 model_lib_v2.py:705] Step 3500 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.058772475,
#  'Loss/localization_loss': 0.013213172,
#  'Loss/regularization_loss': 0.13771465,
#  'Loss/total_loss': 0.2097003,
#  'learning_rate': 0.07948727}
# I0609 16:42:12.993941 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.058772475,
#  'Loss/localization_loss': 0.013213172,
#  'Loss/regularization_loss': 0.13771465,
#  'Loss/total_loss': 0.2097003,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.197s
# I0609 16:42:32.691154 140610980919104 model_lib_v2.py:705] Step 3600 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.09379244,
#  'Loss/localization_loss': 0.018472949,
#  'Loss/regularization_loss': 0.13704531,
#  'Loss/total_loss': 0.2493107,
#  'learning_rate': 0.079445526}
# I0609 16:42:32.691383 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.09379244,
#  'Loss/localization_loss': 0.018472949,
#  'Loss/regularization_loss': 0.13704531,
#  'Loss/total_loss': 0.2493107,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.195s
# I0609 16:42:52.228174 140610980919104 model_lib_v2.py:705] Step 3700 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.06549188,
#  'Loss/localization_loss': 0.024969488,
#  'Loss/regularization_loss': 0.13634878,
#  'Loss/total_loss': 0.22681016,
#  'learning_rate': 0.07940216}
# I0609 16:42:52.228362 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.06549188,
#  'Loss/localization_loss': 0.024969488,
#  'Loss/regularization_loss': 0.13634878,
#  'Loss/total_loss': 0.22681016,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.197s
# I0609 16:43:11.933104 140610980919104 model_lib_v2.py:705] Step 3800 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.054677606,
#  'Loss/localization_loss': 0.011370078,
#  'Loss/regularization_loss': 0.13584355,
#  'Loss/total_loss': 0.20189123,
#  'learning_rate': 0.079357184}
# I0609 16:43:11.933295 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.054677606,
#  'Loss/localization_loss': 0.011370078,
#  'Loss/regularization_loss': 0.13584355,
#  'Loss/total_loss': 0.20189123,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.196s
# I0609 16:43:31.571192 140610980919104 model_lib_v2.py:705] Step 3900 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.057850692,
#  'Loss/localization_loss': 0.01648088,
#  'Loss/regularization_loss': 0.13516907,
#  'Loss/total_loss': 0.20950064,
#  'learning_rate': 0.07931058}
# I0609 16:43:31.571367 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.057850692,
#  'Loss/localization_loss': 0.01648088,
#  'Loss/regularization_loss': 0.13516907,
#  'Loss/total_loss': 0.20950064,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.196s
# I0609 16:43:51.153210 140610980919104 model_lib_v2.py:705] Step 4000 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.061344452,
#  'Loss/localization_loss': 0.01992989,
#  'Loss/regularization_loss': 0.13444965,
#  'Loss/total_loss': 0.21572399,
#  'learning_rate': 0.07926236}
# I0609 16:43:51.153401 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.061344452,
#  'Loss/localization_loss': 0.01992989,
#  'Loss/regularization_loss': 0.13444965,
#  'Loss/total_loss': 0.21572399,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.197s
# I0609 16:44:10.870405 140610980919104 model_lib_v2.py:705] Step 4100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.046910465,
#  'Loss/localization_loss': 0.013309111,
#  'Loss/regularization_loss': 0.13370623,
#  'Loss/total_loss': 0.1939258,
#  'learning_rate': 0.07921253}
# I0609 16:44:10.870618 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.046910465,
#  'Loss/localization_loss': 0.013309111,
#  'Loss/regularization_loss': 0.13370623,
#  'Loss/total_loss': 0.1939258,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.195s
# I0609 16:44:30.381230 140610980919104 model_lib_v2.py:705] Step 4200 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.06638274,
#  'Loss/localization_loss': 0.015094815,
#  'Loss/regularization_loss': 0.13295038,
#  'Loss/total_loss': 0.21442795,
#  'learning_rate': 0.07916109}
# I0609 16:44:30.381403 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.06638274,
#  'Loss/localization_loss': 0.015094815,
#  'Loss/regularization_loss': 0.13295038,
#  'Loss/total_loss': 0.21442795,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.196s
# I0609 16:44:50.015790 140610980919104 model_lib_v2.py:705] Step 4300 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.03967231,
#  'Loss/localization_loss': 0.012298947,
#  'Loss/regularization_loss': 0.13218759,
#  'Loss/total_loss': 0.18415885,
#  'learning_rate': 0.07910804}
# I0609 16:44:50.015969 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.03967231,
#  'Loss/localization_loss': 0.012298947,
#  'Loss/regularization_loss': 0.13218759,
#  'Loss/total_loss': 0.18415885,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.194s
# I0609 16:45:09.445995 140610980919104 model_lib_v2.py:705] Step 4400 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.056112103,
#  'Loss/localization_loss': 0.018853161,
#  'Loss/regularization_loss': 0.131693,
#  'Loss/total_loss': 0.20665827,
#  'learning_rate': 0.07905338}
# I0609 16:45:09.446233 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.056112103,
#  'Loss/localization_loss': 0.018853161,
#  'Loss/regularization_loss': 0.131693,
#  'Loss/total_loss': 0.20665827,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.193s
# I0609 16:45:28.788154 140610980919104 model_lib_v2.py:705] Step 4500 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.05023665,
#  'Loss/localization_loss': 0.013580067,
#  'Loss/regularization_loss': 0.13121822,
#  'Loss/total_loss': 0.19503495,
#  'learning_rate': 0.07899711}
# I0609 16:45:28.788340 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.05023665,
#  'Loss/localization_loss': 0.013580067,
#  'Loss/regularization_loss': 0.13121822,
#  'Loss/total_loss': 0.19503495,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.193s
# I0609 16:45:48.131278 140610980919104 model_lib_v2.py:705] Step 4600 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.039333235,
#  'Loss/localization_loss': 0.011108447,
#  'Loss/regularization_loss': 0.13052924,
#  'Loss/total_loss': 0.18097092,
#  'learning_rate': 0.078939244}
# I0609 16:45:48.131470 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.039333235,
#  'Loss/localization_loss': 0.011108447,
#  'Loss/regularization_loss': 0.13052924,
#  'Loss/total_loss': 0.18097092,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.196s
# I0609 16:46:07.735179 140610980919104 model_lib_v2.py:705] Step 4700 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.08706176,
#  'Loss/localization_loss': 0.033886287,
#  'Loss/regularization_loss': 0.13058838,
#  'Loss/total_loss': 0.25153643,
#  'learning_rate': 0.07887978}
# I0609 16:46:07.735363 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.08706176,
#  'Loss/localization_loss': 0.033886287,
#  'Loss/regularization_loss': 0.13058838,
#  'Loss/total_loss': 0.25153643,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.195s
# I0609 16:46:27.209159 140610980919104 model_lib_v2.py:705] Step 4800 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.06085981,
#  'Loss/localization_loss': 0.016793517,
#  'Loss/regularization_loss': 0.13028222,
#  'Loss/total_loss': 0.20793554,
#  'learning_rate': 0.07881871}
# I0609 16:46:27.209346 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.06085981,
#  'Loss/localization_loss': 0.016793517,
#  'Loss/regularization_loss': 0.13028222,
#  'Loss/total_loss': 0.20793554,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.197s
# I0609 16:46:46.925081 140610980919104 model_lib_v2.py:705] Step 4900 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.05353705,
#  'Loss/localization_loss': 0.013370462,
#  'Loss/regularization_loss': 0.12974824,
#  'Loss/total_loss': 0.19665575,
#  'learning_rate': 0.07875605}
# I0609 16:46:46.925324 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.05353705,
#  'Loss/localization_loss': 0.013370462,
#  'Loss/regularization_loss': 0.12974824,
#  'Loss/total_loss': 0.19665575,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.193s
# I0609 16:47:06.255076 140610980919104 model_lib_v2.py:705] Step 5000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.051611334,
#  'Loss/localization_loss': 0.020274486,
#  'Loss/regularization_loss': 0.12907508,
#  'Loss/total_loss': 0.2009609,
#  'learning_rate': 0.078691795}
# I0609 16:47:06.255270 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.051611334,
#  'Loss/localization_loss': 0.020274486,
#  'Loss/regularization_loss': 0.12907508,
#  'Loss/total_loss': 0.2009609,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.197s
# I0609 16:47:25.987766 140610980919104 model_lib_v2.py:705] Step 5100 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.053005934,
#  'Loss/localization_loss': 0.018442754,
#  'Loss/regularization_loss': 0.12835765,
#  'Loss/total_loss': 0.19980633,
#  'learning_rate': 0.07862595}
# I0609 16:47:25.987955 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.053005934,
#  'Loss/localization_loss': 0.018442754,
#  'Loss/regularization_loss': 0.12835765,
#  'Loss/total_loss': 0.19980633,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.192s
# I0609 16:47:45.171286 140610980919104 model_lib_v2.py:705] Step 5200 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.04331693,
#  'Loss/localization_loss': 0.011151882,
#  'Loss/regularization_loss': 0.12764637,
#  'Loss/total_loss': 0.18211518,
#  'learning_rate': 0.07855851}
# I0609 16:47:45.171471 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.04331693,
#  'Loss/localization_loss': 0.011151882,
#  'Loss/regularization_loss': 0.12764637,
#  'Loss/total_loss': 0.18211518,
# ...
#  'Loss/localization_loss': 0.010933929,
#  'Loss/regularization_loss': 0.083313785,
#  'Loss/total_loss': 0.13314523,
#  'learning_rate': 0.060073983}
# INFO:tensorflow:Step 17400 per-step time 0.196s
# I0609 17:27:29.634949 140610980919104 model_lib_v2.py:705] Step 17400 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.029576715,
#  'Loss/localization_loss': 0.005128251,
#  'Loss/regularization_loss': 0.08303434,
#  'Loss/total_loss': 0.117739305,
#  'learning_rate': 0.05985175}
# I0609 17:27:29.635135 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.029576715,
#  'Loss/localization_loss': 0.005128251,
#  'Loss/regularization_loss': 0.08303434,
#  'Loss/total_loss': 0.117739305,
#  'learning_rate': 0.05985175}
# INFO:tensorflow:Step 17500 per-step time 0.195s
# I0609 17:27:49.177443 140610980919104 model_lib_v2.py:705] Step 17500 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.039581053,
#  'Loss/localization_loss': 0.009810709,
#  'Loss/regularization_loss': 0.082710184,
#  'Loss/total_loss': 0.13210195,
#  'learning_rate': 0.0596287}
# I0609 17:27:49.177630 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.039581053,
#  'Loss/localization_loss': 0.009810709,
#  'Loss/regularization_loss': 0.082710184,
#  'Loss/total_loss': 0.13210195,
#  'learning_rate': 0.0596287}
# INFO:tensorflow:Step 17600 per-step time 0.197s
# I0609 17:28:08.842355 140610980919104 model_lib_v2.py:705] Step 17600 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.034686595,
#  'Loss/localization_loss': 0.008770465,
#  'Loss/regularization_loss': 0.08235471,
#  'Loss/total_loss': 0.12581177,
#  'learning_rate': 0.05940484}
# I0609 17:28:08.842542 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.034686595,
#  'Loss/localization_loss': 0.008770465,
#  'Loss/regularization_loss': 0.08235471,
#  'Loss/total_loss': 0.12581177,
#  'learning_rate': 0.05940484}
# INFO:tensorflow:Step 17700 per-step time 0.196s
# I0609 17:28:28.430198 140610980919104 model_lib_v2.py:705] Step 17700 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.041375082,
#  'Loss/localization_loss': 0.00648774,
#  'Loss/regularization_loss': 0.082107544,
#  'Loss/total_loss': 0.12997037,
#  'learning_rate': 0.059180185}
# I0609 17:28:28.430396 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.041375082,
#  'Loss/localization_loss': 0.00648774,
#  'Loss/regularization_loss': 0.082107544,
#  'Loss/total_loss': 0.12997037,
#  'learning_rate': 0.059180185}
# INFO:tensorflow:Step 17800 per-step time 0.196s
# I0609 17:28:48.006957 140610980919104 model_lib_v2.py:705] Step 17800 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.03378395,
#  'Loss/localization_loss': 0.007085235,
#  'Loss/regularization_loss': 0.08179642,
#  'Loss/total_loss': 0.12266561,
#  'learning_rate': 0.05895474}
# I0609 17:28:48.007133 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.03378395,
#  'Loss/localization_loss': 0.007085235,
#  'Loss/regularization_loss': 0.08179642,
#  'Loss/total_loss': 0.12266561,
#  'learning_rate': 0.05895474}
# INFO:tensorflow:Step 17900 per-step time 0.199s
# I0609 17:29:07.952994 140610980919104 model_lib_v2.py:705] Step 17900 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.038859278,
#  'Loss/localization_loss': 0.007918653,
#  'Loss/regularization_loss': 0.08144618,
#  'Loss/total_loss': 0.1282241,
#  'learning_rate': 0.058728524}
# I0609 17:29:07.953176 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.038859278,
#  'Loss/localization_loss': 0.007918653,
#  'Loss/regularization_loss': 0.08144618,
#  'Loss/total_loss': 0.1282241,
#  'learning_rate': 0.058728524}
# INFO:tensorflow:Step 18000 per-step time 0.201s
# I0609 17:29:28.047266 140610980919104 model_lib_v2.py:705] Step 18000 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.037397128,
#  'Loss/localization_loss': 0.009241184,
#  'Loss/regularization_loss': 0.081129335,
#  'Loss/total_loss': 0.12776765,
#  'learning_rate': 0.058501527}
# I0609 17:29:28.047465 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.037397128,
#  'Loss/localization_loss': 0.009241184,
#  'Loss/regularization_loss': 0.081129335,
#  'Loss/total_loss': 0.12776765,
#  'learning_rate': 0.058501527}
# INFO:tensorflow:Step 18100 per-step time 0.203s
# I0609 17:29:48.302488 140610980919104 model_lib_v2.py:705] Step 18100 per-step time 0.203s
# INFO:tensorflow:{'Loss/classification_loss': 0.03978807,
#  'Loss/localization_loss': 0.008008249,
#  'Loss/regularization_loss': 0.08083641,
#  'Loss/total_loss': 0.12863272,
#  'learning_rate': 0.058273777}
# I0609 17:29:48.302689 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.03978807,
#  'Loss/localization_loss': 0.008008249,
#  'Loss/regularization_loss': 0.08083641,
#  'Loss/total_loss': 0.12863272,
#  'learning_rate': 0.058273777}
# INFO:tensorflow:Step 18200 per-step time 0.202s
# I0609 17:30:08.485872 140610980919104 model_lib_v2.py:705] Step 18200 per-step time 0.202s
# INFO:tensorflow:{'Loss/classification_loss': 0.027967526,
#  'Loss/localization_loss': 0.0072271223,
#  'Loss/regularization_loss': 0.08049143,
#  'Loss/total_loss': 0.115686074,
#  'learning_rate': 0.05804527}
# I0609 17:30:08.486265 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.027967526,
#  'Loss/localization_loss': 0.0072271223,
#  'Loss/regularization_loss': 0.08049143,
#  'Loss/total_loss': 0.115686074,
#  'learning_rate': 0.05804527}
# INFO:tensorflow:Step 18300 per-step time 0.203s
# I0609 17:30:28.835067 140610980919104 model_lib_v2.py:705] Step 18300 per-step time 0.203s
# INFO:tensorflow:{'Loss/classification_loss': 0.030854989,
#  'Loss/localization_loss': 0.0073077013,
#  'Loss/regularization_loss': 0.08015971,
#  'Loss/total_loss': 0.1183224,
#  'learning_rate': 0.05781603}
# I0609 17:30:28.835276 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.030854989,
#  'Loss/localization_loss': 0.0073077013,
#  'Loss/regularization_loss': 0.08015971,
#  'Loss/total_loss': 0.1183224,
#  'learning_rate': 0.05781603}
# INFO:tensorflow:Step 18400 per-step time 0.197s
# I0609 17:30:48.578207 140610980919104 model_lib_v2.py:705] Step 18400 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.030350547,
#  'Loss/localization_loss': 0.008497942,
#  'Loss/regularization_loss': 0.079838805,
#  'Loss/total_loss': 0.118687294,
#  'learning_rate': 0.057586048}
# I0609 17:30:48.578411 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.030350547,
#  'Loss/localization_loss': 0.008497942,
#  'Loss/regularization_loss': 0.079838805,
#  'Loss/total_loss': 0.118687294,
#  'learning_rate': 0.057586048}
# INFO:tensorflow:Step 18500 per-step time 0.201s
# I0609 17:31:08.661731 140610980919104 model_lib_v2.py:705] Step 18500 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.02318256,
#  'Loss/localization_loss': 0.0066774897,
#  'Loss/regularization_loss': 0.079521455,
#  'Loss/total_loss': 0.109381504,
#  'learning_rate': 0.05735535}
# I0609 17:31:08.661953 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.02318256,
#  'Loss/localization_loss': 0.0066774897,
#  'Loss/regularization_loss': 0.079521455,
#  'Loss/total_loss': 0.109381504,
#  'learning_rate': 0.05735535}
# INFO:tensorflow:Step 18600 per-step time 0.204s
# I0609 17:31:29.068874 140610980919104 model_lib_v2.py:705] Step 18600 per-step time 0.204s
# INFO:tensorflow:{'Loss/classification_loss': 0.0533171,
#  'Loss/localization_loss': 0.009701308,
#  'Loss/regularization_loss': 0.07948042,
#  'Loss/total_loss': 0.14249882,
#  'learning_rate': 0.057123937}
# I0609 17:31:29.069074 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.0533171,
#  'Loss/localization_loss': 0.009701308,
#  'Loss/regularization_loss': 0.07948042,
#  'Loss/total_loss': 0.14249882,
#  'learning_rate': 0.057123937}
# INFO:tensorflow:Step 18700 per-step time 0.202s
# I0609 17:31:49.279462 140610980919104 model_lib_v2.py:705] Step 18700 per-step time 0.202s
# INFO:tensorflow:{'Loss/classification_loss': 0.05314176,
#  'Loss/localization_loss': 0.0068271835,
#  'Loss/regularization_loss': 0.07921151,
#  'Loss/total_loss': 0.13918045,
#  'learning_rate': 0.056891818}
# I0609 17:31:49.279648 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.05314176,
#  'Loss/localization_loss': 0.0068271835,
#  'Loss/regularization_loss': 0.07921151,
#  'Loss/total_loss': 0.13918045,
#  'learning_rate': 0.056891818}
# INFO:tensorflow:Step 18800 per-step time 0.201s
# I0609 17:32:09.351719 140610980919104 model_lib_v2.py:705] Step 18800 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.022712724,
#  'Loss/localization_loss': 0.0071295784,
#  'Loss/regularization_loss': 0.07891641,
#  'Loss/total_loss': 0.10875871,
#  'learning_rate': 0.056659}
# I0609 17:32:09.351903 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.022712724,
#  'Loss/localization_loss': 0.0071295784,
#  'Loss/regularization_loss': 0.07891641,
#  'Loss/total_loss': 0.10875871,
#  'learning_rate': 0.056659}
# INFO:tensorflow:Step 18900 per-step time 0.199s
# I0609 17:32:29.226735 140610980919104 model_lib_v2.py:705] Step 18900 per-step time 0.199s
# INFO:tensorflow:{'Loss/classification_loss': 0.03361838,
#  'Loss/localization_loss': 0.008101668,
#  'Loss/regularization_loss': 0.07866328,
#  'Loss/total_loss': 0.12038333,
#  'learning_rate': 0.056425504}
# I0609 17:32:29.226958 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.03361838,
#  'Loss/localization_loss': 0.008101668,
#  'Loss/regularization_loss': 0.07866328,
#  'Loss/total_loss': 0.12038333,
#  'learning_rate': 0.056425504}
# INFO:tensorflow:Step 19000 per-step time 0.200s
# I0609 17:32:49.238526 140610980919104 model_lib_v2.py:705] Step 19000 per-step time 0.200s
# INFO:tensorflow:{'Loss/classification_loss': 0.024625694,
#  'Loss/localization_loss': 0.006190904,
#  'Loss/regularization_loss': 0.078379534,
#  'Loss/total_loss': 0.109196134,
#  'learning_rate': 0.056191333}
# I0609 17:32:49.238729 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.024625694,
#  'Loss/localization_loss': 0.006190904,
#  'Loss/regularization_loss': 0.078379534,
#  'Loss/total_loss': 0.109196134,
#  'learning_rate': 0.056191333}
# INFO:tensorflow:Step 19100 per-step time 0.203s
# I0609 17:33:09.542123 140610980919104 model_lib_v2.py:705] Step 19100 per-step time 0.203s
# INFO:tensorflow:{'Loss/classification_loss': 0.031777035,
#  'Loss/localization_loss': 0.005970009,
#  'Loss/regularization_loss': 0.07809646,
#  'Loss/total_loss': 0.115843505,
#  'learning_rate': 0.055956498}
# I0609 17:33:09.542385 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.031777035,
#  'Loss/localization_loss': 0.005970009,
#  'Loss/regularization_loss': 0.07809646,
#  'Loss/total_loss': 0.115843505,
#  'learning_rate': 0.055956498}
# INFO:tensorflow:Step 19200 per-step time 0.201s
# I0609 17:33:29.624960 140610980919104 model_lib_v2.py:705] Step 19200 per-step time 0.201s
# INFO:tensorflow:{'Loss/classification_loss': 0.035958186,
#  'Loss/localization_loss': 0.0074714185,
#  'Loss/regularization_loss': 0.077781975,
#  'Loss/total_loss': 0.12121158,
#  'learning_rate': 0.055721}
# I0609 17:33:29.625168 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.035958186,
#  'Loss/localization_loss': 0.0074714185,
#  'Loss/regularization_loss': 0.077781975,
#  'Loss/total_loss': 0.12121158,
#  'learning_rate': 0.055721}
# INFO:tensorflow:Step 19300 per-step time 0.197s
# I0609 17:33:49.340527 140610980919104 model_lib_v2.py:705] Step 19300 per-step time 0.197s
# INFO:tensorflow:{'Loss/classification_loss': 0.033356097,
#  'Loss/localization_loss': 0.0064910185,
#  'Loss/regularization_loss': 0.07746917,
#  'Loss/total_loss': 0.11731628,
#  'learning_rate': 0.05548486}
# I0609 17:33:49.340708 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.033356097,
#  'Loss/localization_loss': 0.0064910185,
#  'Loss/regularization_loss': 0.07746917,
#  'Loss/total_loss': 0.11731628,
#  'learning_rate': 0.05548486}
# INFO:tensorflow:Step 19400 per-step time 0.194s
# I0609 17:34:08.792024 140610980919104 model_lib_v2.py:705] Step 19400 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.037859056,
#  'Loss/localization_loss': 0.006719274,
#  'Loss/regularization_loss': 0.07715836,
#  'Loss/total_loss': 0.12173669,
#  'learning_rate': 0.05524808}
# I0609 17:34:08.792213 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.037859056,
#  'Loss/localization_loss': 0.006719274,
#  'Loss/regularization_loss': 0.07715836,
#  'Loss/total_loss': 0.12173669,
#  'learning_rate': 0.05524808}
# INFO:tensorflow:Step 19500 per-step time 0.195s
# I0609 17:34:28.256617 140610980919104 model_lib_v2.py:705] Step 19500 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.046239275,
#  'Loss/localization_loss': 0.01695229,
#  'Loss/regularization_loss': 0.076865636,
#  'Loss/total_loss': 0.1400572,
#  'learning_rate': 0.05501068}
# I0609 17:34:28.256804 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.046239275,
#  'Loss/localization_loss': 0.01695229,
#  'Loss/regularization_loss': 0.076865636,
#  'Loss/total_loss': 0.1400572,
#  'learning_rate': 0.05501068}
# INFO:tensorflow:Step 19600 per-step time 0.198s
# I0609 17:34:48.034764 140610980919104 model_lib_v2.py:705] Step 19600 per-step time 0.198s
# INFO:tensorflow:{'Loss/classification_loss': 0.02670195,
#  'Loss/localization_loss': 0.007300697,
#  'Loss/regularization_loss': 0.07656514,
#  'Loss/total_loss': 0.110567786,
#  'learning_rate': 0.054772656}
# I0609 17:34:48.034965 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.02670195,
#  'Loss/localization_loss': 0.007300697,
#  'Loss/regularization_loss': 0.07656514,
#  'Loss/total_loss': 0.110567786,
#  'learning_rate': 0.054772656}
# INFO:tensorflow:Step 19700 per-step time 0.194s
# I0609 17:35:07.457401 140610980919104 model_lib_v2.py:705] Step 19700 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.034895066,
#  'Loss/localization_loss': 0.0075128004,
#  'Loss/regularization_loss': 0.076260254,
#  'Loss/total_loss': 0.118668124,
#  'learning_rate': 0.05453403}
# I0609 17:35:07.457578 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.034895066,
#  'Loss/localization_loss': 0.0075128004,
#  'Loss/regularization_loss': 0.076260254,
#  'Loss/total_loss': 0.118668124,
#  'learning_rate': 0.05453403}
# INFO:tensorflow:Step 19800 per-step time 0.195s
# I0609 17:35:26.925418 140610980919104 model_lib_v2.py:705] Step 19800 per-step time 0.195s
# INFO:tensorflow:{'Loss/classification_loss': 0.03062266,
#  'Loss/localization_loss': 0.00562513,
#  'Loss/regularization_loss': 0.075972416,
#  'Loss/total_loss': 0.112220205,
#  'learning_rate': 0.0542948}
# I0609 17:35:26.925622 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.03062266,
#  'Loss/localization_loss': 0.00562513,
#  'Loss/regularization_loss': 0.075972416,
#  'Loss/total_loss': 0.112220205,
#  'learning_rate': 0.0542948}
# INFO:tensorflow:Step 19900 per-step time 0.194s
# I0609 17:35:46.329754 140610980919104 model_lib_v2.py:705] Step 19900 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.028608475,
#  'Loss/localization_loss': 0.0068324674,
#  'Loss/regularization_loss': 0.07567446,
#  'Loss/total_loss': 0.1111154,
#  'learning_rate': 0.054054994}
# I0609 17:35:46.329930 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.028608475,
#  'Loss/localization_loss': 0.0068324674,
#  'Loss/regularization_loss': 0.07567446,
#  'Loss/total_loss': 0.1111154,
#  'learning_rate': 0.054054994}
# INFO:tensorflow:Step 20000 per-step time 0.196s
# I0609 17:36:05.931388 140610980919104 model_lib_v2.py:705] Step 20000 per-step time 0.196s
# INFO:tensorflow:{'Loss/classification_loss': 0.035226688,
#  'Loss/localization_loss': 0.008448179,
#  'Loss/regularization_loss': 0.075406924,
#  'Loss/total_loss': 0.119081795,
#  'learning_rate': 0.0538146}
# I0609 17:36:05.931582 140610980919104 model_lib_v2.py:708] {'Loss/classification_loss': 0.035226688,
#  'Loss/localization_loss': 0.008448179,
#  'Loss/regularization_loss': 0.075406924,
#  'Loss/total_loss': 0.119081795,
#  'learning_rate': 0.0538146}

# %% [markdown]
# # 6.&nbsp;Convert Model to TensorFlow Lite

# %%
# Make a directory to store the trained TFLite model
# !mkdir custom_model_lite
output_directory = 'custom_model_lite/'

# Path to training directory (the conversion script automatically chooses the highest checkpoint file)
last_model_path = 'training'

# !python3 models/research/object_detection/export_tflite_graph_tf2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/.venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-06-09 17:38:53.771780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:53.777862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:53.778649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:53.786197: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-09 17:38:53.787324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:53.787778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:53.788053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:54.320471: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:54.320919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:54.320942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 17:38:54.321313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:54.321412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0609 17:38:56.642744 139845178537792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-09 17:38:59.115124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:59.115463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:59.115615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:59.115989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:59.116027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 17:38:59.116218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:38:59.116260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0609 17:38:59.574500 139845178537792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-09 17:39:00.150021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:00.150367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:00.150618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:00.151006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:00.151027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 17:39:00.151299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:00.151339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-06-09 17:39:00.478197: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# I0609 17:39:00.810303 139845178537792 api.py:441] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-06-09 17:39:01.451905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:01.452144: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:01.452411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:01.452718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:01.452741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 17:39:01.452899: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:01.452928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f2f6c061550>, because it is not built.
# W0609 17:39:01.609046 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f2f6c061550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f54149310>, because it is not built.
# W0609 17:39:01.751542 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f54149310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f46236c40>, because it is not built.
# W0609 17:39:01.751709 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f46236c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46228340>, because it is not built.
# W0609 17:39:01.751780 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46228340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46228160>, because it is not built.
# W0609 17:39:01.751840 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46228160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f462285e0>, because it is not built.
# W0609 17:39:01.751896 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f462285e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46228700>, because it is not built.
# W0609 17:39:01.751953 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46228700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46228d30>, because it is not built.
# W0609 17:39:01.752012 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46228d30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f46220850>, because it is not built.
# W0609 17:39:01.752072 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f46220850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46220730>, because it is not built.
# W0609 17:39:01.752129 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46220730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46220b80>, because it is not built.
# W0609 17:39:01.752185 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x7f2f46220b80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f462208e0>, because it is not built.
# W0609 17:39:01.752241 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f462208e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46220670>, because it is not built.
# W0609 17:39:01.752299 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46220670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f541498b0>, because it is not built.
# W0609 17:39:01.752355 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f541498b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46251430>, because it is not built.
# W0609 17:39:01.752412 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f46251430>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47268be0>, because it is not built.
# W0609 17:39:01.752469 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47268be0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f472689a0>, because it is not built.
# W0609 17:39:01.752527 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f472689a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4746d340>, because it is not built.
# W0609 17:39:01.752645 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4746d340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4746d7c0>, because it is not built.
# W0609 17:39:01.752736 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4746d7c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4746dc10>, because it is not built.
# W0609 17:39:01.752795 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4746dc10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4746dd90>, because it is not built.
# W0609 17:39:01.752851 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4746dd90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f541498e0>, because it is not built.
# W0609 17:39:01.752907 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f541498e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f474a5190>, because it is not built.
# W0609 17:39:01.752963 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f474a5190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357dc0>, because it is not built.
# W0609 17:39:01.753020 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357dc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f473575e0>, because it is not built.
# W0609 17:39:01.753076 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f473575e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357310>, because it is not built.
# W0609 17:39:01.753178 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f47357340>, because it is not built.
# W0609 17:39:01.753289 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f47357340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357550>, because it is not built.
# W0609 17:39:01.753366 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47357550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f471fd910>, because it is not built.
# W0609 17:39:01.753517 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f471fd910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f54149910>, because it is not built.
# W0609 17:39:01.753617 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f54149910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f475aeb20>, because it is not built.
# W0609 17:39:01.753682 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f475aeb20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4622f550>, because it is not built.
# W0609 17:39:01.753741 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4622f550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4622f580>, because it is not built.
# W0609 17:39:01.753798 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4622f580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47350370>, because it is not built.
# W0609 17:39:01.753856 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f47350370>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f47350f70>, because it is not built.
# W0609 17:39:01.753914 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f47350f70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4747f340>, because it is not built.
# W0609 17:39:01.753972 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4747f340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4747f7f0>, because it is not built.
# W0609 17:39:01.754039 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4747f7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4627f520>, because it is not built.
# W0609 17:39:01.754103 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f4627f520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4623a640>, because it is not built.
# W0609 17:39:01.754160 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f4623a640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2250>, because it is not built.
# W0609 17:39:01.754217 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d2520>, because it is not built.
# W0609 17:39:01.754274 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d2520>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2940>, because it is not built.
# W0609 17:39:01.754331 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d28b0>, because it is not built.
# W0609 17:39:01.754388 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d28b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2c40>, because it is not built.
# W0609 17:39:01.754445 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f2f461d2c40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d2ee0>, because it is not built.
# W0609 17:39:01.754502 139845178537792 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f2f461d2ee0>, because it is not built.
# W0609 17:39:10.812922 139845178537792 save.py:260] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 104). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: custom_model_lite/saved_model/assets
# I0609 17:39:13.266755 139845178537792 builder_impl.py:779] Assets written to: custom_model_lite/saved_model/assets

# %%
# Convert exported graph file into TFLite model file
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('custom_model_lite/saved_model')
tflite_model = converter.convert()

with open('custom_model_lite/detect.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# 2023-06-09 17:39:15.058496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.063270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.063434: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.064417: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-09 17:39:15.064970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.065243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.065664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.541977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.542321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.542331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1609] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-09 17:39:15.543573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:922] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-09 17:39:15.543615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9408 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs
# 2023-06-09 17:39:20.883936: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-06-09 17:39:20.883987: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# 2023-06-09 17:39:20.884749: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: custom_model_lite/saved_model
# 2023-06-09 17:39:20.931320: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-06-09 17:39:20.931357: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: custom_model_lite/saved_model
# 2023-06-09 17:39:21.064900: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-06-09 17:39:21.585440: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: custom_model_lite/saved_model
# 2023-06-09 17:39:21.860410: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 975665 microseconds.
# 2023-06-09 17:39:22.417365: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-09 17:39:22.992208: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1963] Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs

# %% [markdown]
# ## 6.1&nbsp;Write Metadata to TensorFlow Lite

# %%
# !pip install tflite-support-nightly
# Out:
# Collecting tflite-support-nightly
#   Using cached tflite_support_nightly-0.4.4.dev20230522-cp38-cp38-manylinux2014_x86_64.whl (60.8 MB)
# Requirement already satisfied: absl-py>=0.7.0 in ./.venv/lib/python3.8/site-packages (from tflite-support-nightly) (1.4.0)
# Requirement already satisfied: numpy>=1.20.0 in ./.venv/lib/python3.8/site-packages (from tflite-support-nightly) (1.24.3)
# Requirement already satisfied: flatbuffers>=2.0 in ./.venv/lib/python3.8/site-packages (from tflite-support-nightly) (23.5.26)
# Requirement already satisfied: protobuf<4,>=3.18.0 in ./.venv/lib/python3.8/site-packages (from tflite-support-nightly) (3.20.3)
# Collecting sounddevice>=0.4.4 (from tflite-support-nightly)
#   Using cached sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Collecting pybind11>=2.6.0 (from tflite-support-nightly)
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->tflite-support-nightly)
#   Using cached cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->tflite-support-nightly)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Installing collected packages: pycparser, pybind11, CFFI, sounddevice, tflite-support-nightly
# Successfully installed CFFI-1.15.1 pybind11-2.10.4 pycparser-2.21 sounddevice-0.4.6 tflite-support-nightly-0.4.4.dev20230522

# %%
from tflite_support.metadata_writers import object_detector
from tflite_support.metadata_writers import metadata_info
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata_schema_py_generated as _metadata_fb

# %%
ObjectDetectorWriter = object_detector.MetadataWriter
_MODEL_PATH = "custom_model_lite/detect.tflite"
# Task Library expects label files that are in the same format as the one below.
_LABEL_FILE = "classes.txt"
_SAVE_TO_PATH = "model_metadata.tflite"
# Normalization parameters is required when reprocessing the image. It is
# optional if the image pixel values are in range of [0, 255] and the input
# tensor is quantized to uint8. See the introduction for normalization and
# quantization parameters below for more details.
# https://www.tensorflow.org/lite/models/convert/metadata#normalization_and_quantization_parameters)
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ObjectDetectorWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
from tflite_support import metadata

displayer = metadata.MetadataDisplayer.with_model_file("model_metadata.tflite")
print("Metadata populated:")
print(displayer.get_metadata_json())

print("Associated file(s) populated:")
for file_name in displayer.get_packed_associated_file_list():
  print("file name: ", file_name)
  print("file content:")
  print(displayer.get_associated_file_buffer(file_name))
# Out:
# Metadata populated:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ],
#   "min_parser_version": "1.2.0"
# }
#
# Associated file(s) populated:
# file name:  classes.txt
# file content:
# b'Nol\nSatu\nDua\nTiga\nEmpat\nLima\nEnam\nTujuh\nDelapan\nSembilan\nSepuluh'

# %% [markdown]
# # 7.&nbsp;Testing the Model

# %% [markdown]
# ## 7.1&nbsp;Inference Test Images

# %%
# Script to run custom TFLite model on test images to detect objects
# Source: https://github.com/EdjeElectronics/TensorFlow-Lite-Object-Detection-on-Android-and-Raspberry-Pi/blob/master/TFLite_detection_image.py

# Import packages
import os
import cv2
import numpy as np
import sys
import glob
import random
import importlib.util
from tensorflow.lite.python.interpreter import Interpreter
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

### Define function for inferencing with TFLite model and displaying results

def tflite_detect_images(modelpath, imgpath, lblpath, min_conf, num_test_images, savepath='results', txt_only=False):

  # Grab filenames of all images in test folder
  images = glob.glob(imgpath + '/*.jpg') + glob.glob(imgpath + '/*.JPG') + glob.glob(imgpath + '/*.png') + glob.glob(imgpath + '/*.bmp') + glob.glob(imgpath + '/*.jpeg') 

  # Load the label map into memory
  with open(lblpath, 'r') as f:
      labels = [line.strip() for line in f.readlines()]

  # Load the Tensorflow Lite model into memory
  interpreter = Interpreter(model_path=modelpath)
  interpreter.allocate_tensors()

  # Get model details
  input_details = interpreter.get_input_details()
  output_details = interpreter.get_output_details()
  height = input_details[0]['shape'][1]
  width = input_details[0]['shape'][2]

  float_input = (input_details[0]['dtype'] == np.float32)

  input_mean = 127.5
  input_std = 127.5

  # Randomly select test images
  images_to_test = random.sample(images, num_test_images)

  # Loop over every image and perform detection
  for image_path in images_to_test:

      # Load image and resize to expected shape [1xHxWx3]
      image = cv2.imread(image_path)
      image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      imH, imW, _ = image.shape 
      image_resized = cv2.resize(image_rgb, (width, height))
      input_data = np.expand_dims(image_resized, axis=0)

      # Normalize pixel values if using a floating model (i.e. if model is non-quantized)
      if float_input:
          input_data = (np.float32(input_data) - input_mean) / input_std

      # Perform the actual detection by running the model with the image as input
      interpreter.set_tensor(input_details[0]['index'],input_data)
      interpreter.invoke()

      # Retrieve detection results
      boxes = interpreter.get_tensor(output_details[1]['index'])[0] # Bounding box coordinates of detected objects
      classes = interpreter.get_tensor(output_details[3]['index'])[0] # Class index of detected objects
      scores = interpreter.get_tensor(output_details[0]['index'])[0] # Confidence of detected objects

      detections = []

      # Loop over all detections and draw detection box if confidence is above minimum threshold
      for i in range(len(scores)):
          if ((scores[i] > min_conf) and (scores[i] <= 1.0)):

              # Get bounding box coordinates and draw box
              # Interpreter can return coordinates that are outside of image dimensions, need to force them to be within image using max() and min()
              ymin = int(max(1,(boxes[i][0] * imH)))
              xmin = int(max(1,(boxes[i][1] * imW)))
              ymax = int(min(imH,(boxes[i][2] * imH)))
              xmax = int(min(imW,(boxes[i][3] * imW)))
              
              cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (10, 255, 0), 2)

              # Draw label
              object_name = labels[int(classes[i])] # Look up object name from "labels" array using class index
              label = '%s: %d%%' % (object_name, int(scores[i]*100)) # Example: 'person: 72%'
              labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2) # Get font size
              label_ymin = max(ymin, labelSize[1] + 10) # Make sure not to draw label too close to top of window
              cv2.rectangle(image, (xmin, label_ymin-labelSize[1]-10), (xmin+labelSize[0], label_ymin+baseLine-10), (255, 255, 255), cv2.FILLED) # Draw white box to put label text in
              cv2.putText(image, label, (xmin, label_ymin-7), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2) # Draw label text

              detections.append([object_name, scores[i], xmin, ymin, xmax, ymax])

      
      # All the results have been drawn on the image, now display the image
      if txt_only == False: # "text_only" controls whether we want to display the image results or just save them in .txt files
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(12,16))
        plt.imshow(image)
        plt.show()
      
      # Save detection results in .txt files (for calculating mAP)
      elif txt_only == True:

        # Get filenames and paths
        image_fn = os.path.basename(image_path)      
        base_fn, ext = os.path.splitext(image_fn)
        txt_result_fn = base_fn +'.txt'
        txt_savepath = os.path.join(savepath, txt_result_fn)

        # Write results to text file
        # (Using format defined by https://github.com/Cartucho/mAP, which will make it easy to calculate mAP)
        with open(txt_savepath,'w') as f:
            for detection in detections:
                f.write('%s %.4f %d %d %d %d\n' % (detection[0], detection[1], detection[2], detection[3], detection[4], detection[5]))

  return

# %%
# Set up variables for running user's model
PATH_TO_IMAGES='images/test/'   # Path to test images folder
PATH_TO_MODEL='custom_model_lite/detect.tflite'   # Path to .tflite model file
PATH_TO_LABELS='classes.txt'   # Path to labelmap.txt file
min_conf_threshold=0.8   # Confidence threshold (try changing this to 0.01 if you don't see any detection results)
images_to_test=5   # Number of images to run detection on

# Run inferencing function!
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test)

# %% [markdown]
# ## 7.2.&nbsp;Calculate mAP

# %%
# !git clone https://github.com/Cartucho/mAP mAP
# %cd mAP
# !rm input/detection-results/* 
# !rm input/ground-truth/* 
# !rm input/images-optional/* 
# !wget https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/calculate_map_cartucho_modified.py
# %cd ..
# Out:
# Cloning into 'mAP'...
# remote: Enumerating objects: 908, done.
# remote: Total 908 (delta 0), reused 0 (delta 0), pack-reused 908
# Receiving objects: 100% (908/908), 14.71 MiB | 1.92 MiB/s, done.
# Resolving deltas: 100% (321/321), done.
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# --2023-06-09 17:40:34--  https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/calculate_map_cartucho_modified.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5268 (5.1K) [text/plain]
# Saving to: ‘calculate_map_cartucho_modified.py’
#
# calculate_map_cartu 100%[===================>]   5.14K  --.-KB/s    in 0.02s
#
# 2023-06-09 17:40:35 (341 KB/s) - ‘calculate_map_cartucho_modified.py’ saved [5268/5268]
#
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka

# %%
# !cp images/test/* mAP/input/images-optional # Copy images and xml files
# !mv mAP/input/images-optional/*.xml mAP/input/ground-truth/  # Move xml files to the appropriate folder

# %%
# !python mAP/scripts/extra/convert_gt_xml.py
# Out:
# Conversion completed!

# %%
# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='images/test'   # Path to test images folder
PATH_TO_MODEL='model_metadata.tflite'   # Path to .tflite model file
PATH_TO_LABELS='classes.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.8 # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp') + glob.glob(PATH_TO_IMAGES + '/*.jpeg')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')
# Out:
# Starting inference on 182 images...
# Finished inferencing!

# %%
#if there a space in classes, ex: Terima Kasih
# %cd mAP/
# !wget https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/remove_spaces_modified.py
# %cd ..
# !python3 mAP/remove_spaces_modified.py
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# --2023-06-09 17:41:00--  https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/remove_spaces_modified.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882 (1.8K) [text/plain]
# Saving to: ‘remove_spaces_modified.py’
#
# remove_spaces_modif 100%[===================>]   1.84K  --.-KB/s    in 0.001s
#
# 2023-06-09 17:41:01 (3.26 MB/s) - ‘remove_spaces_modified.py’ saved [1882/1882]
#
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka
# Done!

# %%
# !cp classes.txt mAP/

# %%
# %cd mAP/
# !python3 scripts/extra/intersect-gt-and-dr.py
# !python3 calculate_map_cartucho_modified.py --labels=classes.txt
# %cd ..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# total ground-truth files: 182
# total detection-results files: 182
#
# No backup required for /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP/input/ground-truth
# No backup required for /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP/input/detection-results
# total intersected files: 182
# Intersection completed!
# Calculating mAP at 0.50 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.55 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.60 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.65 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.70 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.75 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.80 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 99.11%
# Calculating mAP at 0.85 IoU threshold...
# 100.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 100.00% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 84.07% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.66%
# Calculating mAP at 0.90 IoU threshold...
# 100.00% = Delapan AP
# 68.98% = Dua AP
# 82.09% = Empat AP
# 78.77% = Enam AP
# 93.36% = Lima AP
# 58.68% = Nol AP
# 76.99% = Satu AP
# 68.81% = Sembilan AP
# 81.78% = Sepuluh AP
# 84.07% = Tiga AP
# 88.78% = Tujuh AP
# mAP = 80.21%
# Calculating mAP at 0.95 IoU threshold...
# 22.38% = Delapan AP
# 5.27% = Dua AP
# 25.00% = Empat AP
# 36.51% = Enam AP
# 18.75% = Lima AP
# 20.83% = Nol AP
# 6.68% = Satu AP
# 19.31% = Sembilan AP
# 15.56% = Sepuluh AP
# 3.17% = Tiga AP
# 19.94% = Tujuh AP
# mAP = 17.58%
#
# ***mAP Results***
#
# Class		Average mAP @ 0.5:0.95
# ---------------------------------------
# Nol		87.95%
# Satu		88.37%
# Dua		83.42%
# Tiga		87.13%
# Empat		90.71%
# Lima		91.21%
# Enam		91.53%
# Tujuh		90.87%
# Delapan		92.24%
# Sembilan		85.00%
# Sepuluh		89.73%
#
# Overall		88.92%
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka

# %% [markdown]
# # 8. Post-Training Quantization

# %%
# Get list of all images in train directory
image_path = 'images/train'

jpg_file_list = glob.glob(image_path + '/*.jpg')
JPG_file_list = glob.glob(image_path + '/*.JPG')
png_file_list = glob.glob(image_path + '/*.png')
bmp_file_list = glob.glob(image_path + '/*.bmp')
jpeg_file_list = glob.glob(image_path + '/*.jpeg')

quant_image_list = jpg_file_list + JPG_file_list + png_file_list + bmp_file_list + jpeg_file_list

# %%
# A generator that provides a representative dataset
# Code modified from https://colab.research.google.com/github/google-coral/tutorials/blob/master/retrain_classification_ptq_tf2.ipynb

# First, get input details for model so we know how to preprocess images
interpreter = Interpreter(model_path=PATH_TO_MODEL)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
height = input_details[0]['shape'][1]
width = input_details[0]['shape'][2]

import random

def representative_data_gen():
  dataset_list = quant_image_list
  quant_num = 300
  for i in range(quant_num):
    pick_me = random.choice(dataset_list)
    image = tf.io.read_file(pick_me)

    if pick_me.endswith('.jpg') or pick_me.endswith('.JPG') or pick_me.endswith('.jpeg'):
      image = tf.io.decode_jpeg(image, channels=3)
    elif pick_me.endswith('.png'):
      image = tf.io.decode_png(image, channels=3)
    elif pick_me.endswith('.bmp'):
      image = tf.io.decode_bmp(image, channels=3)

    image = tf.image.resize(image, [width, height])
    image = tf.cast(image / 255., tf.float32)
    image = tf.expand_dims(image, 0)
    yield [image]

# %%
# Initialize converter module
converter = tf.lite.TFLiteConverter.from_saved_model('custom_model_lite/saved_model')

# This enables quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# This sets the representative dataset for quantization
converter.representative_dataset = representative_data_gen
# This ensures that if any ops can't be quantized, the converter throws an error
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# For full integer quantization, though supported types defaults to int8 only, we explicitly declare it for clarity.
converter.target_spec.supported_types = [tf.int8]
# These set the input tensors to uint8 and output tensors to float32
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.float32
tflite_model = converter.convert()

with open('custom_model_lite/detect_quant.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# 2023-06-09 17:47:46.194362: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-06-09 17:47:46.194404: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# 2023-06-09 17:47:46.194581: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: custom_model_lite/saved_model
# 2023-06-09 17:47:46.237540: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-06-09 17:47:46.237577: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: custom_model_lite/saved_model
# 2023-06-09 17:47:46.370023: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-06-09 17:47:46.896840: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: custom_model_lite/saved_model
# 2023-06-09 17:47:47.158228: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 963648 microseconds.
# 2023-06-09 17:47:48.249836: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1963] Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs
# Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs
# Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: 3, output_inference_type: 0
# 2023-06-09 17:48:30.263887: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1963] Estimated count of arithmetic ops: 1.739 G  ops, equivalently 0.870 G  MACs

# %% [markdown]
# ## 8.1&nbsp;Write Metadata to TensorFlow Lite

# %%
from tflite_support.metadata_writers import object_detector
from tflite_support.metadata_writers import metadata_info
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata_schema_py_generated as _metadata_fb

# %%
ObjectDetectorWriter = object_detector.MetadataWriter
_MODEL_PATH = "custom_model_lite/detect_quant.tflite"
# Task Library expects label files that are in the same format as the one below.
_LABEL_FILE = "classes.txt"
_SAVE_TO_PATH = "model_metadata_quant.tflite"
# Normalization parameters is required when reprocessing the image. It is
# optional if the image pixel values are in range of [0, 255] and the input
# tensor is quantized to uint8. See the introduction for normalization and
# quantization parameters below for more details.
# https://www.tensorflow.org/lite/models/convert/metadata#normalization_and_quantization_parameters)
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ObjectDetectorWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               255.0
#             ],
#             "min": [
#               0.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
from tflite_support import metadata

displayer = metadata.MetadataDisplayer.with_model_file("model_metadata.tflite")
print("Metadata populated:")
print(displayer.get_metadata_json())

print("Associated file(s) populated:")
for file_name in displayer.get_packed_associated_file_list():
  print("file name: ", file_name)
  print("file content:")
  print(displayer.get_associated_file_buffer(file_name))
# Out:
# Metadata populated:
# {
#   "name": "ObjectDetector",
#   "description": "Identify which of a known set of objects might be present and provide information about their positions within the given image or a video stream.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be detected.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
#       ],
#       "output_tensor_metadata": [
#         {
#           "name": "score",
#           "description": "The scores of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "location",
#           "description": "The locations of the detected boxes.",
#           "content": {
#             "content_properties_type": "BoundingBoxProperties",
#             "content_properties": {
#               "index": [
#                 1,
#                 0,
#                 3,
#                 2
#               ],
#               "type": "BOUNDARIES"
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "number of detections",
#           "description": "The number of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             }
#           },
#           "stats": {
#           }
#         },
#         {
#           "name": "category",
#           "description": "The categories of the detected boxes.",
#           "content": {
#             "content_properties_type": "FeatureProperties",
#             "content_properties": {
#             },
#             "range": {
#               "min": 2,
#               "max": 2
#             }
#           },
#           "stats": {
#           },
#           "associated_files": [
#             {
#               "name": "classes.txt",
#               "description": "Labels for categories that the model can recognize.",
#               "type": "TENSOR_VALUE_LABELS"
#             }
#           ]
#         }
#       ],
#       "output_tensor_groups": [
#         {
#           "name": "detection_result",
#           "tensor_names": [
#             "location",
#             "category",
#             "score"
#           ]
#         }
#       ]
#     }
#   ],
#   "min_parser_version": "1.2.0"
# }
#
# Associated file(s) populated:
# file name:  classes.txt
# file content:
# b'Nol\nSatu\nDua\nTiga\nEmpat\nLima\nEnam\nTujuh\nDelapan\nSembilan\nSepuluh'

# %% [markdown]
# ## 8.2&nbsp; Calculate mAP

# %%
# %cd mAP
# !rm -rf input/detection-results/* 
# !rm -rf input/ground-truth/* 
# !rm -rf input/images-optional/* 
# %cd ..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka

# %%
# !cp images/test/* mAP/input/images-optional # Copy images and xml files
# !mv mAP/input/images-optional/*.xml mAP/input/ground-truth/  # Move xml files to the appropriate folder

# %%
# !python mAP/scripts/extra/convert_gt_xml.py
# Out:
# Conversion completed!

# %%
# Set up variables for running inference, this time to get detection results saved as .txt files
PATH_TO_IMAGES='images/test'   # Path to test images folder
PATH_TO_MODEL='model_metadata_quant.tflite'   # Path to .tflite model file
PATH_TO_LABELS='classes.txt'   # Path to labelmap.txt file
PATH_TO_RESULTS='mAP/input/detection-results' # Folder to save detection results in
min_conf_threshold=0.8 # Confidence threshold

# Use all the images in the test folder
image_list = glob.glob(PATH_TO_IMAGES + '/*.jpg') + glob.glob(PATH_TO_IMAGES + '/*.JPG') + glob.glob(PATH_TO_IMAGES + '/*.png') + glob.glob(PATH_TO_IMAGES + '/*.bmp') + glob.glob(PATH_TO_IMAGES + '/*.jpeg')
images_to_test = min(500, len(image_list)) # If there are more than 500 images in the folder, just use 500

# Tell function to just save results and not display images
txt_only = True

# Run inferencing function!
print('Starting inference on %d images...' % images_to_test)
tflite_detect_images(PATH_TO_MODEL, PATH_TO_IMAGES, PATH_TO_LABELS, min_conf_threshold, images_to_test, PATH_TO_RESULTS, txt_only)
print('Finished inferencing!')
# Out:
# Starting inference on 182 images...
# Finished inferencing!

# %%
# !cp classes.txt mAP/

# %%
#if there a space in classes, ex: Terima Kasih
# %cd mAP/
# !wget https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/remove_spaces_modified.py
# %cd ..
# !python3 mAP/remove_spaces_modified.py
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# --2023-06-08 06:25:41--  https://raw.githubusercontent.com/Patuli-Pahlawan-Tuli/Patuli-ML/main/utils/remove_spaces_modified.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882 (1.8K) [text/plain]
# Saving to: ‘remove_spaces_modified.py’
#
# remove_spaces_modif 100%[===================>]   1.84K  --.-KB/s    in 0s
#
# 2023-06-08 06:25:43 (19.1 MB/s) - ‘remove_spaces_modified.py’ saved [1882/1882]
#
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka
# Done!

# %%
# !rm -rf mAP/outputs
# %cd mAP/
# !python3 scripts/extra/intersect-gt-and-dr.py
# !python3 calculate_map_cartucho_modified.py --labels=classes.txt
# %cd ..
# Out:
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP
# total ground-truth files: 182
# total detection-results files: 182
#
# No backup required for /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP/input/ground-truth
# No backup required for /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka/mAP/input/detection-results
# total intersected files: 182
# Intersection completed!
# Calculating mAP at 0.50 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.55 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.60 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.65 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.70 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.75 IoU threshold...
# 95.00% = Delapan AP
# 95.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 100.00% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 97.05%
# Calculating mAP at 0.80 IoU threshold...
# 95.00% = Delapan AP
# 90.00% = Dua AP
# 100.00% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 100.00% = Sepuluh AP
# 92.86% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 95.95%
# Calculating mAP at 0.85 IoU threshold...
# 95.00% = Delapan AP
# 82.22% = Dua AP
# 88.28% = Empat AP
# 100.00% = Enam AP
# 100.00% = Lima AP
# 100.00% = Nol AP
# 82.35% = Satu AP
# 95.24% = Sembilan AP
# 93.33% = Sepuluh AP
# 73.08% = Tiga AP
# 100.00% = Tujuh AP
# mAP = 91.77%
# Calculating mAP at 0.90 IoU threshold...
# 75.30% = Delapan AP
# 63.93% = Dua AP
# 33.17% = Empat AP
# 74.12% = Enam AP
# 61.25% = Lima AP
# 55.00% = Nol AP
# 69.75% = Satu AP
# 62.54% = Sembilan AP
# 46.15% = Sepuluh AP
# 37.14% = Tiga AP
# 83.02% = Tujuh AP
# mAP = 60.12%
# Calculating mAP at 0.95 IoU threshold...
# 24.69% = Delapan AP
# 1.84% = Dua AP
# 0.69% = Empat AP
# 30.39% = Enam AP
# 15.62% = Lima AP
# 1.39% = Nol AP
# 0.00% = Satu AP
# 24.72% = Sembilan AP
# 16.51% = Sepuluh AP
# 19.25% = Tiga AP
# 7.14% = Tujuh AP
# mAP = 12.93%
#
# ***mAP Results***
#
# Class		Average mAP @ 0.5:0.95
# ---------------------------------------
# Nol		85.64%
# Satu		72.85%
# Dua		80.80%
# Tiga		82.23%
# Empat		82.21%
# Lima		87.69%
# Enam		90.45%
# Tujuh		89.02%
# Delapan		86.00%
# Sembilan		84.92%
# Sepuluh		85.60%
#
# Overall		84.31%
# /home/dadang/Documents/ML/Bangkit/train_huruf/local_angka
